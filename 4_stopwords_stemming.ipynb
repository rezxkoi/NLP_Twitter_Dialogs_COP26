# %% [markdown]
# ## Applying stop-words

# %%
import pandas as pd
import numpy as np
import pickle
import os

import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("seaborn-dark")

from gensim import matutils, models
import gensim.corpora as corpora
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
import scipy.sparse

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, ENGLISH_STOP_WORDS
from sklearn.decomposition import NMF, TruncatedSVD, LatentDirichletAllocation

# %%
en_df = pd.read_csv('english_clean_df.csv')

# %%
en_df
# Out:
#            twitter_id                                            content  \
# 0        aquitainexox  @Banterm42404691 @MrHarryCole Absolutely one s...
# 1        GEC_JCM_Info  Please join us at a #COP26 side event "Impleme...
# 2              zpnine  #India’s huge solar uptake has boosted #climat...
# 3             PGDynes  The concrete needed to accommodate 2 billion m...
# 4             Xplorit  #WestVirginia Senator &amp; Ennersystams fraud...
# ...               ...                                                ...
# 5949   AqsaYounasRana  ClimateChange is no more only a challenge, it’...
# 5950       pete4peace  We confronted the coal baron this morning! Fuc...
# 5951  mmill_landscape  Feeling simply disgusted by countries such as ...
# 5952      KarynCaplan  🚨 Join us in calling for @Google and #Facebook...
# 5953           DrDuly  There is no doubt! "The science is clear: to k...
#
#                                           removed_links  \
# 0     @Banterm42404691 @MrHarryCole Absolutely one s...
# 1     Please join us at a #COP26 side event "Impleme...
# 2     #India’s huge solar uptake has boosted #climat...
# 3     The concrete needed to accommodate 2 billion m...
# 4     #WestVirginia Senator &amp; Ennersystams fraud...
# ...                                                 ...
# 5949  ClimateChange is no more only a challenge, it’...
# 5950  We confronted the coal baron this morning! Fuc...
# 5951  Feeling simply disgusted by countries such as ...
# 5952  🚨 Join us in calling for @Google and #Facebook...
# 5953  There is no doubt! "The science is clear: to k...
#
#                                           removed_users  \
# 0       Absolutely one self indulgent ego trip!! #COP26
# 1     Please join us at a #COP26 side event "Impleme...
# 2     #India’s huge solar uptake has boosted #climat...
# 3     The concrete needed to accommodate 2 billion m...
# 4     #WestVirginia Senator &amp; Ennersystams fraud...
# ...                                                 ...
# 5949  ClimateChange is no more only a challenge, it’...
# 5950  We confronted the coal baron this morning! Fuc...
# 5951  Feeling simply disgusted by countries such as ...
# 5952  🚨 Join us in calling for  and #Facebook () to ...
# 5953  There is no doubt! "The science is clear: to k...
#
#                                        removed_hashtags  \
# 0             Absolutely one self indulgent ego trip!!
# 1     Please join us at a  side event "Implementing ...
# 2     ’s huge solar uptake has boosted  goals, says ...
# 3     The concrete needed to accommodate 2 billion m...
# 4      Senator &amp; Ennersystams fraud . gets a pro...
# ...                                                 ...
# 5949  ClimateChange is no more only a challenge, it’...
# 5950  We confronted the coal baron this morning! Fuc...
# 5951  Feeling simply disgusted by countries such as ...
# 5952  🚨 Join us in calling for  and  () to stop prom...
# 5953  There is no doubt! "The science is clear: to k...
#
#                                              removed_av  \
# 0             Absolutely one self indulgent ego trip!!
# 1     Please join us at a  side event "Implementing ...
# 2     ’s huge solar uptake has boosted  goals, says ...
# 3     The concrete needed to accommodate 2 billion m...
# 4      Senator &amp; Ennersystams fraud . gets a pro...
# ...                                                 ...
# 5949  ClimateChange is no more only a challenge, it’...
# 5950  We confronted the coal baron this morning! Fuc...
# 5951  Feeling simply disgusted by countries such as ...
# 5952  🚨 Join us in calling for  and  () to stop prom...
# 5953  There is no doubt! "The science is clear: to k...
#
#                                                  tokens  \
# 0                    absolutely self indulgent ego trip
# 1     join event implement joint credit mechanism jc...
# 2            huge solar uptake boost goals say minister
# 3     concrete need accommodate billion people citie...
# 4     senator amp ennersystams fraud get proper welc...
# ...                                                 ...
# 5949  climatechange challenge crisis soon catastroph...
# 5950                   confront coal baron morning fuck
# 5951  feel simply disgust countries sign decrease st...
# 5952  join call stop promote fund climate denial pub...
# 5953  doubt science clear warm degrees cut global em...
#
#                                              lemmatized lang
# 0                    absolutely self indulgent ego trip   en
# 1     join event implement joint credit mechanism jc...   en
# 2            huge solar uptake boost goals say minister   en
# 3     concrete need accommodate billion people citie...   en
# 4     senator amp ennersystams fraud get proper welc...   en
# ...                                                 ...  ...
# 5949  climatechange challenge crisis soon catastroph...   en
# 5950                   confront coal baron morning fuck   en
# 5951  feel simply disgust countries sign decrease st...   en
# 5952  join call stop promote fund climate denial pub...   en
# 5953  doubt science clear warm degrees cut global em...   en
#
# [5954 rows x 9 columns]

# %%
#NLTK Stop words
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from gensim.utils import simple_preprocess

stop_words = stopwords.words('english')
stop_words.extend(['amp'])


# Define functions for stopwords
def remove_stopwords(texts):
    return[[word for word in simple_preprocess(str(doc)) \
            if word not in stop_words] for doc in texts]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/amirreza/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(en_df['lemmatized'])
# Out:
# 0                      absolutely self indulgent ego trip
# 1       join event implement joint credit mechanism jc...
# 2              huge solar uptake boost goals say minister
# 3       concrete need accommodate billion people citie...
# 4       senator amp ennersystams fraud get proper welc...
#                               ...
# 5949    climatechange challenge crisis soon catastroph...
# 5950                     confront coal baron morning fuck
# 5951    feel simply disgust countries sign decrease st...
# 5952    join call stop promote fund climate denial pub...
# 5953    doubt science clear warm degrees cut global em...
# Name: lemmatized, Length: 5954, dtype: object

# %%
en_df['stop_word'] = remove_stopwords(en_df['lemmatized'])

# %%
en_df.head()
# Out:
#      twitter_id                                            content  \
# 0  aquitainexox  @Banterm42404691 @MrHarryCole Absolutely one s...
# 1  GEC_JCM_Info  Please join us at a #COP26 side event "Impleme...
# 2        zpnine  #India’s huge solar uptake has boosted #climat...
# 3       PGDynes  The concrete needed to accommodate 2 billion m...
# 4       Xplorit  #WestVirginia Senator &amp; Ennersystams fraud...
#
#                                        removed_links  \
# 0  @Banterm42404691 @MrHarryCole Absolutely one s...
# 1  Please join us at a #COP26 side event "Impleme...
# 2  #India’s huge solar uptake has boosted #climat...
# 3  The concrete needed to accommodate 2 billion m...
# 4  #WestVirginia Senator &amp; Ennersystams fraud...
#
#                                        removed_users  \
# 0    Absolutely one self indulgent ego trip!! #COP26
# 1  Please join us at a #COP26 side event "Impleme...
# 2  #India’s huge solar uptake has boosted #climat...
# 3  The concrete needed to accommodate 2 billion m...
# 4  #WestVirginia Senator &amp; Ennersystams fraud...
#
#                                     removed_hashtags  \
# 0          Absolutely one self indulgent ego trip!!
# 1  Please join us at a  side event "Implementing ...
# 2  ’s huge solar uptake has boosted  goals, says ...
# 3  The concrete needed to accommodate 2 billion m...
# 4   Senator &amp; Ennersystams fraud . gets a pro...
#
#                                           removed_av  \
# 0          Absolutely one self indulgent ego trip!!
# 1  Please join us at a  side event "Implementing ...
# 2  ’s huge solar uptake has boosted  goals, says ...
# 3  The concrete needed to accommodate 2 billion m...
# 4   Senator &amp; Ennersystams fraud . gets a pro...
#
#                                               tokens  \
# 0                 absolutely self indulgent ego trip
# 1  join event implement joint credit mechanism jc...
# 2         huge solar uptake boost goals say minister
# 3  concrete need accommodate billion people citie...
# 4  senator amp ennersystams fraud get proper welc...
#
#                                           lemmatized lang  \
# 0                 absolutely self indulgent ego trip   en
# 1  join event implement joint credit mechanism jc...   en
# 2         huge solar uptake boost goals say minister   en
# 3  concrete need accommodate billion people citie...   en
# 4  senator amp ennersystams fraud get proper welc...   en
#
#                                            stop_word
# 0           [absolutely, self, indulgent, ego, trip]
# 1  [join, event, implement, joint, credit, mechan...
# 2  [huge, solar, uptake, boost, goals, say, minis...
# 3  [concrete, need, accommodate, billion, people,...
# 4  [senator, ennersystams, fraud, get, proper, we...

# %%
#print(remove_stopwords(en_df['lemmatized']))

# %% [markdown]
# ## Stemming

# %%
sno = nltk.stem.SnowballStemmer('english')

# %%
sno.stem('absolutely')
# Out:
# 'absolut'

# %%
stop_w_all = []
#stop_w = []
for i in range(len(en_df['stop_word'])):
    stop_w = []
    for x in en_df['stop_word'][i]:
        stop_w.append(sno.stem(x))
    stop_w_all.append(stop_w)
#id_tweet_df['lemmatized'] = lemmatized

# %%
stop_w_all
# Out:
# [['absolut', 'self', 'indulg', 'ego', 'trip'],
#  ['join',
#   'event',
#   'implement',
#   'joint',
#   'credit',
#   'mechan',
#   'jcm',
#   'creat',
#   'benefit',
#   'stakehold',
#   'nov',
#   'jst',
#   'ishihara',
#   'gec',
#   'discuss',
#   'jcm',
#   'sdgs',
#   'event',
#   'stream',
#   'onlin'],
#  ['huge', 'solar', 'uptak', 'boost', 'goal', 'say', 'minist'],
#  ['concret',
#   'need',
#   'accommod',
#   'billion',
#   'peopl',
#   'citi',
#   'year',
#   'blow',
#   'carbon',
#   'budget'],
#  ['senat',
#   'ennersystam',
#   'fraud',
#   'get',
#   'proper',
#   'welcom',
#   'world',
#   'famous',
#   'obstruct',
#   'rube',
#   'manchin',
#   'greed',
#   'threaten',
#   'life',
#   'earth',
#   'investig'],
#  ['today',
#   'energi',
#   'day',
#   'end',
#   'coal',
#   'singl',
#   'biggest',
#   'contributor',
#   'sight',
#   'thank',
#   'secur',
#   'strong',
#   'coalit',
#   'countri',
#   'organis',
#   'today',
#   'read'],
#  ['way', 'futur', 'generat', 'emb', 'work', 'import'],
#  ['work',
#   'quito',
#   'school',
#   'produc',
#   'excit',
#   'new',
#   'websit',
#   'launch',
#   'soon',
#   'aim',
#   'share',
#   'understand',
#   'risk',
#   'grind',
#   'chang',
#   'climat'],
#  ['climat',
#   'confer',
#   'say',
#   'longer',
#   'king',
#   'special',
#   'littl',
#   'prime',
#   'minist',
#   'scott',
#   'morrison',
#   'say',
#   'fuck',
#   'aukus'],
#  ['join',
#   'urg',
#   'commit',
#   'billion',
#   'annual',
#   'intern',
#   'addit',
#   'develop',
#   'budget',
#   'fund',
#   'support',
#   'adapt',
#   'measur'],
#  ['gentl',
#   'pray',
#   'care',
#   'steward',
#   'creation',
#   'commit',
#   'protect',
#   'life',
#   'human',
#   'digniti',
#   'god',
#   'creation',
#   'selfish',
#   'wast',
#   'ruthless',
#   'destroy',
#   'good',
#   'earth',
#   'listen',
#   'poor'],
#  ['global',
#   'citizen',
#   'speak',
#   'clear',
#   'messag',
#   'defend',
#   'planet',
#   'need',
#   'listen',
#   'need',
#   'act'],
#  ['look', 'interest', 'event', 'look'],
#  ['meaningless',
#   'india',
#   'china',
#   'includ',
#   'commit',
#   'phase',
#   'coal',
#   'commit',
#   'countri',
#   'pledg',
#   'climat',
#   'summit',
#   'end',
#   'use',
#   'coal',
#   'power'],
#  ['wait', 'love', 'world', 'love', 'window', 'communiti', 'year'],
#  ['energi',
#   'theme',
#   'day',
#   'climat',
#   'confer',
#   'spearhead',
#   'deal',
#   'end',
#   'financ',
#   'fossil',
#   'fuel',
#   'project',
#   'abroad',
#   'countri',
#   'expect',
#   'pledg',
#   'phase',
#   'coal',
#   'fuel',
#   'power'],
#  ['hear',
#   'urgent',
#   'global',
#   'citizen',
#   'count',
#   'offer',
#   'bold',
#   'commit',
#   'local',
#   'global',
#   'climat',
#   'action'],
#  ['pupil',
#   'recognis',
#   'climat',
#   'action',
#   'new',
#   'scheme',
#   'announc',
#   'day',
#   'youth',
#   'activist',
#   'protest'],
#  ['shun',
#   'flagship',
#   'coal',
#   'pact',
#   'deal',
#   'sever',
#   'blow',
#   'draw',
#   'warn',
#   'world',
#   'lead',
#   'energi',
#   'bodi',
#   'say',
#   'chanc',
#   'limit',
#   'global',
#   'warm',
#   'goal',
#   'accord',
#   'close',
#   'zero'],
#  ['day',
#   'help',
#   'launch',
#   'set',
#   'pioneer',
#   'principl',
#   'defin',
#   'code',
#   'conduct',
#   'strateg',
#   'energi',
#   'plan',
#   'read',
#   'blog',
#   'eeg',
#   'director'],
#  ['time',
#   'ride',
#   'wave',
#   'link',
#   'trend',
#   'twitter',
#   'trash',
#   'memecoin',
#   'shitcoin',
#   'need',
#   'transpar',
#   'tech',
#   'help',
#   'world',
#   'let',
#   'fuck',
#   'game',
#   'begin',
#   'climat',
#   'situat',
#   'wors',
#   'know',
#   'need'],
#  ['recent',
#   'arrest',
#   'hereditari',
#   'chief',
#   'dsta',
#   'hyl',
#   'right',
#   'climat',
#   'summit',
#   'monitor',
#   'pipelin',
#   'construct',
#   'territori',
#   'environment',
#   'assess',
#   'offic',
#   'state'],
#  ['chilean', 'repudi', 'govern', 'violenc', 'mapuch', 'nation'],
#  ['learn',
#   'project',
#   'promot',
#   'sustain',
#   'develop',
#   'region',
#   'accord',
#   'geograph',
#   'environment',
#   'condit',
#   'video',
#   'seri',
#   'youtub',
#   'channel',
#   'event',
#   'websit'],
#  ['bori',
#   'johnson',
#   'privat',
#   'jet',
#   'import',
#   'booz',
#   'dinner',
#   'mat',
#   'think',
#   'need',
#   'detox',
#   'weekend',
#   'scotland',
#   'wonder',
#   'get',
#   'pay',
#   'presenc'],
#  ['xijip', 'absent', 'say', 'link'],
#  ['nan'],
#  ['lil', 'thing', 'òissanc'],
#  ['tri', 'reduc', 'carbonara', 'footprint'],
#  ['healthcar',
#   'crisi',
#   'human',
#   'health',
#   'planetari',
#   'health',
#   'great',
#   'talk',
#   'public',
#   'today',
#   'health',
#   'impact',
#   'climat',
#   'crisi',
#   'climat',
#   'clinic'],
#  ['need', 'break', 'news', 'coverag', 'network', 'head', 'fox'],
#  ['staff',
#   'student',
#   'ask',
#   'live',
#   'music',
#   'come',
#   'start',
#   'saturday',
#   'live',
#   'music',
#   'sunday',
#   'wed',
#   'thursday',
#   'week',
#   'stay',
#   'tune',
#   'updat'],
#  ['belov',
#   'countri',
#   'hear',
#   'voic',
#   'rep',
#   'pat',
#   'earth',
#   'way',
#   'busi',
#   'buy',
#   'gen',
#   'car',
#   'look',
#   'matter'],
#  ['commit',
#   'actual',
#   'take',
#   'action',
#   'differ',
#   'thing',
#   'mean',
#   'mean',
#   'right'],
#  ['beauti',
#   'messag',
#   'queen',
#   'collect',
#   'climat',
#   'chang',
#   'princ',
#   'phillip',
#   'give',
#   'warn',
#   'unfold',
#   'today',
#   'climat',
#   'chang',
#   'children',
#   'queen',
#   'speech',
#   'cop'],
#  ['big', 'sham', 'disappoint'],
#  ['nan'],
#  ['sad',
#   'panel',
#   'member',
#   'view',
#   'polici',
#   'wrong',
#   'sure',
#   'fall',
#   'short',
#   'assumpt',
#   'primari',
#   'determin',
#   'find',
#   'money',
#   'privat',
#   'financ',
#   'gov',
#   'tax',
#   'gov',
#   'currenc',
#   'issuer',
#   'money',
#   'fit',
#   'cost',
#   'cont'],
#  ['nan'],
#  ['heat', 'say', 'talk', 'negoti', 'fun', 'game', 'ocean', 'rise', 'guess'],
#  ['pledg', 'limit', 'time', 'snap', 'analysi', 'find', 'today', 'news'],
#  ['pilgrim', 'bbc', 'sound', 'day', 'week'],
#  ['land',
#   'use',
#   'indigen',
#   'peopl',
#   'mean',
#   'sort',
#   'fair',
#   'use',
#   'ancestr',
#   'land',
#   'better',
#   'true'],
#  ['australia',
#   'plan',
#   'achiev',
#   'net',
#   'zero',
#   'emiss',
#   'key',
#   'inflect',
#   'point',
#   'push',
#   'futur',
#   'run',
#   'renew',
#   'energi',
#   'call',
#   'swift',
#   'action',
#   'octob',
#   'newslett'],
#  ['nan'],
#  ['cop',
#   'far',
#   'phase',
#   'worri',
#   'hear',
#   'talk',
#   'peopl',
#   'need',
#   'sure',
#   'piec',
#   'climat',
#   'action',
#   'need',
#   'away',
#   'carbon'],
#  ['reason', 'huge', 'farc'],
#  ['ukrain',
#   'join',
#   'lead',
#   'net',
#   'zero',
#   'world',
#   'initi',
#   'initi',
#   'ukrain',
#   'abl',
#   'access',
#   'expertis',
#   'depart',
#   'energi',
#   'order',
#   'implement',
#   'project',
#   'decarbonis'],
#  ['sci',
#   'second',
#   'press',
#   'confer',
#   'featur',
#   'special',
#   'guest',
#   'speaker',
#   'karina',
#   'larsen',
#   'watch',
#   'today',
#   'import',
#   'discuss',
#   'learn',
#   'differ',
#   'opportun',
#   'unit',
#   'technolog',
#   'centr',
#   'network'],
#  ['share',
#   'postcard',
#   'real',
#   'paper',
#   'folk',
#   'meet',
#   'contact',
#   'info',
#   'busi',
#   'card',
#   'think',
#   'appreci',
#   'aspen',
#   'draw',
#   'leopold',
#   'quot',
#   'creat',
#   'connect'],
#  ['endless',
#   'laugh',
#   'touch',
#   'touch',
#   'check',
#   'read',
#   'let',
#   'ask',
#   'rest',
#   'help',
#   'print',
#   'trillion',
#   'increas',
#   'emiss'],
#  ['itali', 'turn', 'backlash', 'origin', 'plot'],
#  ['nan'],
#  ['massiv', 'job', 'leav', 'ambit', 'deliveri'],
#  ['distort',
#   'west',
#   'coverag',
#   'china',
#   'half',
#   'emiss',
#   'capita',
#   'greenhous',
#   'gas',
#   'emiss',
#   'china',
#   'global',
#   'ev',
#   'make',
#   'world',
#   'solar',
#   'panel',
#   'electr',
#   'bus'],
#  ['today',
#   'highlight',
#   'meet',
#   'inspir',
#   'climat',
#   'justic',
#   'peac',
#   'activist',
#   'push',
#   'coupl',
#   'month',
#   'walk',
#   'london',
#   'glasgow',
#   'speak',
#   'thousand',
#   'school',
#   'kid',
#   'way',
#   'read'],
#  ['nan'],
#  ['quick', 'way', 'meat'],
#  ['negoti', 'expect', 'tension', 'china', 'cop', 'talk', 'heat', 'axio'],
#  ['nan'],
#  ['world',
#   'look',
#   'step',
#   'effort',
#   'cut',
#   'emiss',
#   'effort',
#   'near',
#   'strong',
#   'report',
#   'find',
#   'growth',
#   'impact',
#   'far',
#   'outpac',
#   'effort',
#   'launch'],
#  ['nicola', 'sturgeon', 'urg', 'interven', 'heavi', 'hand', 'polic'],
#  ['watch',
#   'say',
#   'coal',
#   'longer',
#   'king',
#   'time',
#   'wider',
#   'communiti',
#   'start',
#   'refer',
#   'morrison',
#   'king',
#   'canut'],
#  ['fall', 'bullsh', 'god', 'open', 'ing', 'eye'],
#  ['guess',
#   'bomb',
#   'dispos',
#   'team',
#   'snip',
#   'wrong',
#   'wire',
#   'clock',
#   'doomsday',
#   'devic',
#   'tick',
#   'get',
#   'bomb',
#   'dispos',
#   'team',
#   'site',
#   'start',
#   'snip',
#   'wire',
#   'hope',
#   'right',
#   'one'],
#  ['rag'],
#  ['congratul',
#   'mayor',
#   'garcetti',
#   'announc',
#   'yesterday',
#   'mayor',
#   'citi',
#   'pledg',
#   'goal',
#   'reach',
#   'net',
#   'zero',
#   'emiss',
#   'cut',
#   'fair',
#   'share',
#   'global',
#   'emiss',
#   'half'],
#  ['join',
#   'live',
#   'onlin',
#   'glasgow',
#   'mon',
#   'nov',
#   'gmt',
#   'acdt',
#   'blue',
#   'zone',
#   'scottish',
#   'event',
#   'campus',
#   'aust',
#   'gov',
#   'pavilion',
#   'hall',
#   'regist'],
#  ['incred',
#   'night',
#   'brilliant',
#   'show',
#   'thank',
#   'put',
#   'amaz',
#   'exchang',
#   'cultur',
#   'honour',
#   'amnesti',
#   'thank',
#   'thank',
#   'awesom',
#   'venu'],
#  ['transform',
#   'australia',
#   'laggard',
#   'leader',
#   'cana',
#   'event',
#   'bst',
#   'aedt',
#   'tonight',
#   'live',
#   'stream',
#   'event',
#   'repres',
#   'aus',
#   'civil',
#   'societi',
#   'voic'],
#  ['stuff', 'get', 'think', 'get', 'updat', 'hole', 'ozon', 'layer', 'talk'],
#  ['nan'],
#  ['white',
#   'hous',
#   'aid',
#   'travel',
#   'biden',
#   'test',
#   'posit',
#   'quarantin',
#   'scotland',
#   'bloomberg'],
#  ['communiti',
#   'strateg',
#   'peopl',
#   'face',
#   'climat',
#   'chang',
#   'tradit',
#   'environment',
#   'icon',
#   'polar',
#   'bear',
#   'forest',
#   'polit',
#   'leader',
#   'inclin',
#   'action'],
#  ['increas', 'evapor', 'water', 'cycl', 'intensifi', 'climat', 'warm'],
#  ['give', 'keynot', 'incentiv', 'renew', 'energi'],
#  ['thinnest',
#   'represent',
#   'island',
#   'cop',
#   'say',
#   'ambassador',
#   'new',
#   'york',
#   'travel',
#   'issu',
#   'leav',
#   'pacif',
#   'nation',
#   'risk',
#   'rise',
#   'sea',
#   'littl',
#   'voic',
#   'climat',
#   'summit',
#   'glasgow'],
#  ['hypocrit',
#   'leader',
#   'global',
#   'local',
#   'level',
#   'treat',
#   'bad',
#   'profit',
#   'hell',
#   'line',
#   'disast',
#   'invit',
#   'weak',
#   'leader',
#   'mann',
#   'extinct'],
#  ['hear', 'countri'],
#  ['say', 'christian', 'background', 'antichrist'],
#  ['paul',
#   'polman',
#   'say',
#   'stop',
#   'compet',
#   'futur',
#   'human',
#   'start',
#   'work',
#   'climat',
#   'action'],
#  ['think',
#   'strong',
#   'project',
#   'thank',
#   'share',
#   'wonder',
#   'opportun',
#   'best',
#   'wish',
#   'team',
#   'member'],
#  ['great',
#   'thread',
#   'line',
#   'let',
#   'toast',
#   'glasgow',
#   'toast',
#   'pre',
#   'cop',
#   'piec',
#   'great',
#   'guy'],
#  ['attende',
#   'know',
#   'break',
#   'day',
#   'sunday',
#   'wonder',
#   'farmer',
#   'offer',
#   'look',
#   'farm',
#   'min',
#   'outsid',
#   'glasgow'],
#  ['nan'],
#  ['say',
#   'invest',
#   'protect',
#   'ecosystem',
#   'creat',
#   'tripl',
#   'benefit',
#   'address',
#   'climat',
#   'chang',
#   'biodivers',
#   'crisi',
#   'improv',
#   'socio',
#   'econom',
#   'outcom'],
#  ['presid',
#   'buhari',
#   'pledg',
#   'invest',
#   'infrastructur',
#   'develop',
#   'nigeria',
#   'high',
#   'level',
#   'event'],
#  ['event', 'newton', 'saturday', 'nov'],
#  ['prime',
#   'minist',
#   'join',
#   'world',
#   'leader',
#   'environment',
#   'group',
#   'decri',
#   'continu',
#   'inact',
#   'halt',
#   'coal',
#   'gas',
#   'emiss',
#   'generat',
#   'project'],
#  ['advoc',
#   'reactor',
#   'aid',
#   'renew',
#   'nuclear',
#   'power',
#   'nexus',
#   'reliabl',
#   'grid',
#   'mitig'],
#  ['go',
#   'march',
#   'saturday',
#   'glasgow',
#   'go',
#   'great',
#   'day',
#   'flag',
#   'fli',
#   'scotland',
#   'demonstr',
#   'weather',
#   'spectrum',
#   'week'],
#  ['read',
#   'slowli',
#   'coupl',
#   'time',
#   'digest',
#   'small',
#   'print',
#   'understand',
#   'talk',
#   'negoti',
#   'usual',
#   'short',
#   'term',
#   'ism'],
#  ['give', 'keynot', 'stress', 'incentiv', 'renew', 'energi'],
#  ['amaz', 'initi', 'indonesia', 'continu', 'leadership'],
#  ['strateg',
#   'energi',
#   'dialogu',
#   'deepen',
#   'collabor',
#   'area',
#   'clean',
#   'energi',
#   'technolog',
#   'industri',
#   'decarbonis',
#   'nuclear',
#   'energi',
#   'energi',
#   'secur',
#   'scienc',
#   'innov'],
#  ['year',
#   'time',
#   'current',
#   'law',
#   'student',
#   'qcs',
#   'judg',
#   'climat',
#   'version',
#   'nuremberg',
#   'trial',
#   'ceo',
#   'oil',
#   'compani',
#   'complicit',
#   'politician',
#   'dither'],
#  ['big', 'yin', 'big', 'smoke', 'tammi', 'norri', 'glasgow', 'street'],
#  ['big', 'yin', 'big', 'smoke', 'tammi', 'norri', 'glasgow', 'street'],
#  ['nan'],
#  ['look',
#   'like',
#   'fire',
#   'tame',
#   'wtf',
#   'happen',
#   'mean',
#   'averag',
#   'moder',
#   'agnost',
#   'religi',
#   'lean',
#   'death',
#   'cult',
#   'shoot',
#   'raptur',
#   'head'],
#  ['good', 'summari', 'issu'],
#  ['think',
#   'greenwash',
#   'festiv',
#   'continu',
#   'busi',
#   'usual',
#   'tell',
#   'chang',
#   'individu',
#   'lifestyl',
#   'rich',
#   'power',
#   'win',
#   'chang',
#   'privat',
#   'jet',
#   'shift',
#   'blame',
#   'respons'],
#  ['iec',
#   'join',
#   'even',
#   'discuss',
#   'intern',
#   'effort',
#   'confront',
#   'climat',
#   'crisi',
#   'lead',
#   'illinoi',
#   'deleg',
#   'tout',
#   'leadership',
#   'climat',
#   'action',
#   'watch',
#   'live'],
#  ['import', 'read', 'thread'],
#  ['good',
#   'thought',
#   'farmer',
#   'writer',
#   'like',
#   'restor',
#   'soil',
#   'habitat',
#   'make',
#   'live',
#   'farm',
#   'learn',
#   'lot',
#   'recommend',
#   'farmer',
#   'like',
#   'round',
#   'tabl'],
#  ['attend',
#   'event',
#   'live',
#   'democratis',
#   'decarbonis',
#   'global',
#   'progress',
#   'politician',
#   'forc',
#   'action',
#   'gmt',
#   'monday',
#   'novemb',
#   'rsvp'],
#  ['check', 'cultur', 'recommend', 'person', 'event', 'glasgow'],
#  ['greater', 'govanhil', 'cic'],
#  ['nan'],
#  ['new',
#   'podcast',
#   'angus',
#   'gidley',
#   'baird',
#   'senior',
#   'protein',
#   'analyst',
#   'fall',
#   'sheep',
#   'price',
#   'resili',
#   'record',
#   'beef',
#   'price'],
#  ['nan'],
#  ['immor', 'unjust'],
#  ['day',
#   'stomach',
#   'rampant',
#   'stupid',
#   'watch',
#   'leader',
#   'extol',
#   'renew',
#   'brain',
#   'know',
#   'useless',
#   'send',
#   'bar',
#   'wind',
#   'blow',
#   'sun',
#   'shine'],
#  ['bezo',
#   'ceo',
#   'space',
#   'indigen',
#   'leader',
#   'mean',
#   'corpor',
#   'world',
#   'democrat',
#   'world',
#   'repres',
#   'consumpt',
#   'pattern',
#   'bring',
#   'chao',
#   'willing',
#   'humankind',
#   'better',
#   'world'],
#  ['catch', 'photo', 'coal', 'love', 'receiv', 'dose', 'tour'],
#  ['releas',
#   'methan',
#   'melt',
#   'permafrost',
#   'wors',
#   'thaw',
#   'arctic',
#   'permafrost',
#   'climat',
#   'chang'],
#  ['announc', 'new', 'target', 'power', 'deriv', 'govern', 'turn'],
#  ['australian',
#   'govern',
#   'gas',
#   'lead',
#   'recoveri',
#   'rest',
#   'world',
#   'gas',
#   'new',
#   'coal',
#   'need',
#   'slash',
#   'gas',
#   'use'],
#  ['super', 'bowl'],
#  ['crap', 'eco', 'terrorist', 'want', 'dri', 'destroy', 'water', 'sourc'],
#  ['mysteri',
#   'man',
#   'walk',
#   'walk',
#   'confer',
#   'wear',
#   'bomb',
#   'vest',
#   'claim',
#   'affili',
#   'pro',
#   'cum',
#   'extremist'],
#  ['nan'],
#  ['nan'],
#  ['give', 'keynot', 'increas', 'incent', 'renew', 'energi'],
#  ['natur',
#   'gas',
#   'bridg',
#   'fuel',
#   'fossil',
#   'fuel',
#   'say',
#   'hare',
#   'chief',
#   'execut',
#   'climat',
#   'analyt',
#   'bewar',
#   'substitut'],
#  ['lji', 'airlin', 'fer', 'alt', 'see', 'time'],
#  ['moe', 'emphas', 'key', 'tackl', 'healthier', 'futur', 'address', 'event'],
#  ['today',
#   'theme',
#   'focus',
#   'transit',
#   'clean',
#   'energi',
#   'sourc',
#   'acceler',
#   'clean',
#   'energi',
#   'heart',
#   'busi',
#   'product',
#   'butanol',
#   'advanc',
#   'sustain',
#   'biofuel',
#   'instead',
#   'fossil',
#   'fuel'],
#  ['crap', 'eco', 'terrorist', 'want', 'dri', 'destroy', 'water', 'sourc'],
#  ['mayb', 'excit', 'thing', 'go', 'glasgow'],
#  ['talk',
#   'word',
#   'parti',
#   'believ',
#   'climat',
#   'chang',
#   'real',
#   'tri',
#   'fool',
#   'think',
#   'stupid',
#   'good',
#   'luck'],
#  ['scotland', 'glasgow', 'unit', 'kingdom'],
#  ['consid',
#   'climat',
#   'emerg',
#   'make',
#   'million',
#   'billion',
#   'renew',
#   'damn',
#   'good',
#   'thing',
#   'greta',
#   'time',
#   'walk',
#   'swim',
#   'home'],
#  ['chanc',
#   'talk',
#   'climat',
#   'goal',
#   'meet',
#   'louisiana',
#   'opportun',
#   'chang',
#   'energi',
#   'industri'],
#  ['today',
#   'day',
#   'confer',
#   'chanc',
#   'meet',
#   'discuss',
#   'climat',
#   'clean',
#   'energi',
#   'resili',
#   'prioriti',
#   'collabor',
#   'busi',
#   'local',
#   'state',
#   'govern',
#   'effect',
#   'address',
#   'chang',
#   'climat'],
#  ['week',
#   'show',
#   'vision',
#   'louisiana',
#   'remain',
#   'leader',
#   'energi',
#   'mean',
#   'embrac',
#   'transit',
#   'go',
#   'happen',
#   'world',
#   'market',
#   'chang',
#   'sure',
#   'chang'],
#  ['biden',
#   'elect',
#   'world',
#   'respect',
#   'china',
#   'dude',
#   'senil',
#   'pussi',
#   'gonna',
#   'pant',
#   'world',
#   'steal',
#   'lunch',
#   'money'],
#  ['face',
#   'purpos',
#   'sidelin',
#   'margin',
#   'voic',
#   'frontlin',
#   'communiti',
#   'global',
#   'south'],
#  ['speak', 'australia', 'bang', 'govt', 'juic', 'media', 'warn', 'sweari'],
#  ['futur',
#   'energi',
#   'scenario',
#   'net',
#   'zero',
#   'need',
#   'terawatt',
#   'hour',
#   'storag',
#   'coir',
#   'glas',
#   'talk',
#   'gigawatt',
#   'hour',
#   'julian',
#   'lesli',
#   'nation',
#   'grid',
#   'eso'],
#  ['join',
#   'eddi',
#   'perez',
#   'technic',
#   'director',
#   'global',
#   'wash',
#   'share',
#   'critic',
#   'prioriti',
#   'govern',
#   'privat',
#   'agenc',
#   'consid',
#   'mobil',
#   'invest',
#   'climat',
#   'resili',
#   'water',
#   'sector',
#   'project',
#   'est'],
#  ['decarbon',
#   'import',
#   'uplift',
#   'vulner',
#   'underserv',
#   'communiti',
#   'join',
#   'ncel',
#   'virtual',
#   'hear',
#   'state',
#   'legisl',
#   'work',
#   'ensur',
#   'equit',
#   'transit',
#   'net',
#   'zero',
#   'emiss',
#   'regist'],
#  ['environ',
#   'minist',
#   'hold',
#   'cheakamus',
#   'communiti',
#   'forest',
#   'offset',
#   'project',
#   'develop',
#   'exampl',
#   'success',
#   'offset',
#   'project',
#   'vision',
#   'futur',
#   'old',
#   'growth',
#   'protect',
#   'reconcili',
#   'provinc'],
#  ['decad',
#   'experi',
#   'bleach',
#   'longer',
#   'luxuri',
#   'studi',
#   'individu',
#   'climat',
#   'relat',
#   'event',
#   'unpreced',
#   'rare',
#   'pratchett'],
#  ['world',
#   'biggest',
#   'pollut',
#   'use',
#   'social',
#   'media',
#   'obfusc',
#   'climat',
#   'chang',
#   'accord',
#   'far',
#   'year',
#   'run',
#   'ad',
#   'total',
#   'million',
#   'impress'],
#  ['impact',
#   'climat',
#   'chang',
#   'prevent',
#   'million',
#   'girl',
#   'complet',
#   'educ',
#   'girl',
#   'educ',
#   'power',
#   'tool',
#   'help',
#   'tackl',
#   'climat',
#   'crisi',
#   'watch',
#   'panel',
#   'nov',
#   'rsvp'],
#  ['opec', 'terrorist', 'financi'],
#  ['direct', 'action', 'stipul', 'year', 'old'],
#  ['import',
#   'report',
#   'victorian',
#   'environ',
#   'especi',
#   'state',
#   'forest',
#   'misus',
#   'futur',
#   'generat'],
#  ['welcom',
#   'woodland',
#   'methodist',
#   'get',
#   'lot',
#   'tea',
#   'coffe',
#   'pastri',
#   'prayer'],
#  ['global', 'north', 'greenwash', 'festiv', 'greta', 'thunberg'],
#  ['remark', 'speech', 'worth', 'listen', 'singl', 'word'],
#  ['enjoy', 'sumptuous', 'scent', 'black', 'rise', 'oud', 'treat'],
#  ['world',
#   'leader',
#   'go',
#   'worri',
#   'immedi',
#   'threaten',
#   'incom',
#   'power',
#   'definit',
#   'crise',
#   'cost',
#   'younger',
#   'generat',
#   'futur'],
#  ['usual',
#   'ironi',
#   'intern',
#   'call',
#   'leader',
#   'rail',
#   'tri',
#   'kill',
#   'nuclear',
#   'power',
#   'benefit',
#   'electr',
#   'provid',
#   'scotland',
#   'nuclear',
#   'power',
#   'plant'],
#  ['leader',
#   'talk',
#   'impact',
#   'climat',
#   'crisi',
#   'children',
#   'turn',
#   'word',
#   'meaning',
#   'action',
#   'actual',
#   'consid',
#   'children',
#   'gautam',
#   'narasimhan',
#   'unicef',
#   'climat',
#   'lead'],
#  ['award',
#   'seal',
#   'organ',
#   'roadmap',
#   'place',
#   'achiev',
#   'net',
#   'zero',
#   'sooner',
#   'view',
#   'award',
#   'winner'],
#  ['join',
#   'peopl',
#   'differ',
#   'faith',
#   'faith',
#   'discuss',
#   'faith',
#   'base',
#   'organis',
#   'tackl',
#   'climat',
#   'chang',
#   'free',
#   'event'],
#  ['enjoy', 'sumptuous', 'scent', 'black', 'rise', 'oud'],
#  ['young',
#   'expertis',
#   'bold',
#   'creativ',
#   'compromis',
#   'world',
#   'opportun',
#   'achiev',
#   'real',
#   'gender',
#   'transform',
#   'chanc',
#   'build',
#   'dignifi',
#   'harmoni',
#   'livabl',
#   'futur'],
#  ['world', 'need', 'action', 'climat', 'climat', 'action', 'unit', 'nation'],
#  ['taylor',
#   'repeat',
#   'morrison',
#   'lie',
#   'australia',
#   'reduct',
#   'target',
#   'australia',
#   'publish',
#   'target',
#   'morrison',
#   'govern',
#   'coalit',
#   'partner',
#   'public',
#   'reject',
#   'target',
#   'legisl',
#   'reduct'],
#  ['enjoy', 'sumptuous', 'scent', 'black', 'rise', 'oud'],
#  ['meet',
#   'climat',
#   'lawyer',
#   'help',
#   'write',
#   'pari',
#   'agreement',
#   'superglu',
#   'shell'],
#  ['want',
#   'thank',
#   'marda',
#   'kern',
#   'ecoart',
#   'connect',
#   'facilit',
#   'particip',
#   'week',
#   'introduc',
#   'wonder',
#   'peopl',
#   'check',
#   'fantast'],
#  ['warm',
#   'desicc',
#   'deforest',
#   'fire',
#   'land',
#   'area',
#   'effect',
#   'climat',
#   'chang',
#   'land',
#   'resourc',
#   'unit',
#   'state'],
#  ['fascin', 'watch', 'news', 'pilgrim', 'know', 'colleagu'],
#  ['film',
#   'show',
#   'open',
#   'ceremoni',
#   'climat',
#   'summit',
#   'current',
#   'take',
#   'place',
#   'glasgow'],
#  ['glasgow', 'glori'],
#  ['power',
#   'best',
#   'solut',
#   'far',
#   'total',
#   'greenhous',
#   'gas',
#   'emiss',
#   'fourth'],
#  ['million',
#   'peopl',
#   'displac',
#   'insid',
#   'countri',
#   'climat',
#   'chang',
#   'say',
#   'climat',
#   'crisi',
#   'look',
#   'like',
#   'number'],
#  ['honor'],
#  ['kid',
#   'school',
#   'work',
#   'home',
#   'statement',
#   'true',
#   'absolut',
#   'love',
#   'work',
#   'home',
#   'happen',
#   'wfh',
#   'commut',
#   'pollut'],
#  ['speech',
#   'serena',
#   'bashel',
#   'member',
#   'youth',
#   'coalit',
#   'panel',
#   'discuss',
#   'role',
#   'play'],
#  ['futur',
#   'belong',
#   'fast',
#   'extract',
#   'insight',
#   'data',
#   'faster',
#   'winner',
#   'ceo',
#   'great',
#   'discuss',
#   'washington',
#   'sustain',
#   'busi',
#   'model'],
#  ['good',
#   'climat',
#   'news',
#   'icymi',
#   'australia',
#   'energi',
#   'miner',
#   'need',
#   'world',
#   'hit',
#   'actual',
#   'zero',
#   'emiss'],
#  ['speak',
#   'nat',
#   'lib',
#   'backbench',
#   'morrison',
#   'return',
#   'furious',
#   'french',
#   'submarin',
#   'bungl',
#   'think',
#   'govt',
#   'scare',
#   'campaign',
#   'seat',
#   'backfir',
#   'surpris',
#   'challeng',
#   'come'],
#  ['slow',
#   'climat',
#   'chang',
#   'coastal',
#   'communiti',
#   'forc',
#   'rise',
#   'sea',
#   'level',
#   'global',
#   'home',
#   'underwat',
#   'year',
#   'england',
#   'imagin',
#   'mean',
#   'entir',
#   'popul',
#   'live',
#   'near',
#   'sea',
#   'level'],
#  ['whilst',
#   'world',
#   'leader',
#   'discuss',
#   'solut',
#   'energi',
#   'transit',
#   'australia',
#   'biggest',
#   'coal',
#   'miner',
#   'shift',
#   'profit',
#   'aus',
#   'switzerland',
#   'avoid',
#   'tax',
#   'undermin',
#   'tax',
#   'base',
#   'transit',
#   'read',
#   'latest',
#   'report'],
#  ['nan'],
#  ['pretti',
#   'cool',
#   'listen',
#   'adventur',
#   'especi',
#   'right',
#   'way',
#   'jam',
#   'levell',
#   'interview',
#   'marc',
#   'goodchild',
#   'climat',
#   'action',
#   'day',
#   'check',
#   'adventur'],
#  ['differ',
#   'good',
#   'perfect',
#   'complet',
#   'unsatisfactori',
#   'attende',
#   'believ',
#   'confer',
#   'peopl',
#   'allow',
#   'critic',
#   'futur',
#   'talk',
#   'healthi',
#   'planet',
#   'right',
#   'privileg'],
#  ['an',
#   'confer',
#   'parti',
#   'unit',
#   'nation',
#   'climat',
#   'chang',
#   'confer',
#   'join'],
#  ['feel', 'paralyz', 'face', 'climat', 'chang', 'tri', 'listen', 'women'],
#  ['nan'],
#  ['great',
#   'speech',
#   'vision',
#   'clariti',
#   'sharp',
#   'uplift',
#   'univers',
#   'true',
#   'captiv',
#   'like',
#   'dream',
#   'littl',
#   'better',
#   'appreci',
#   'languag',
#   'express',
#   'histori',
#   'rememb'],
#  ['countri',
#   'pledg',
#   'phase',
#   'coal',
#   'dirtiest',
#   'fossil',
#   'fuel',
#   'biggest',
#   'coal',
#   'consum',
#   'notabl',
#   'absent',
#   'accord',
#   'includ',
#   'china',
#   'india',
#   'australia'],
#  ['quiet', 'friend', 'get', 'shit', 'thread', 'day'],
#  ['person',
#   'reflect',
#   'day',
#   'success',
#   'day',
#   'level',
#   'special',
#   'thank',
#   'mod',
#   'panellist',
#   'marit',
#   'reigstad',
#   'noel',
#   'keenlysid',
#   'advis',
#   'bat',
#   'cave'],
#  ['mcgt', 'coastguard', 'kingdom', 'alt', 'see', 'time'],
#  ['ultim',
#   'reduc',
#   'market',
#   'coal',
#   'impact',
#   'major',
#   'export',
#   'australia',
#   'includ',
#   'say',
#   'climat',
#   'energi',
#   'director',
#   'speak',
#   'german',
#   'news',
#   'outlet',
#   'big',
#   'anti',
#   'coal',
#   'day',
#   'info'],
#  ['thank', 'feel', 'way'],
#  ['live', 'tweet', 'understand', 'tucker'],
#  ['derail', 'rich', 'world', 'meet', 'oblig', 'poor', 'larri', 'elliott'],
#  ['nan'],
#  ['interest',
#   'governor',
#   'degamo',
#   'sign',
#   'declar',
#   'coal',
#   'subnat',
#   'offici'],
#  ['nan'],
#  ['alberta', 'need', 'listen', 'voic', 'like', 'alistair'],
#  ['block',
#   'block',
#   'communiti',
#   'communiti',
#   'financ',
#   'local',
#   'climat',
#   'solut',
#   'inclus',
#   'impact',
#   'invest',
#   'let'],
#  ['climat',
#   'model',
#   'fail',
#   'dismal',
#   'predict',
#   'futur',
#   'temperatur',
#   'fail',
#   'predict',
#   'past',
#   'unelect',
#   'claim',
#   'know',
#   'occur',
#   'unelect',
#   'use',
#   'junk',
#   'scienc'],
#  ['continu',
#   'wonder',
#   'step',
#   'fight',
#   'clearloop',
#   'compani',
#   'offset',
#   'carbon',
#   'footprint',
#   'help',
#   'build',
#   'brand',
#   'new',
#   'farm',
#   'curious',
#   'loop'],
#  ['end', 'financ', 'fossil', 'fuel', 'project', 'start'],
#  ['person',
#   'reflect',
#   'day',
#   'success',
#   'day',
#   'level',
#   'special',
#   'thank',
#   'mod',
#   'panellist',
#   'marit',
#   'reigstad',
#   'noel',
#   'keenlysid',
#   'advis',
#   'bat',
#   'cave'],
#  ['climat',
#   'model',
#   'fail',
#   'dismal',
#   'predict',
#   'futur',
#   'temperatur',
#   'fail',
#   'predict',
#   'past',
#   'unelect',
#   'claim',
#   'know',
#   'occur',
#   'unelect',
#   'use',
#   'junk',
#   'scienc'],
#  ['nan'],
#  ['wow', 'fabul', 'speech'],
#  ['bring',
#   'game',
#   'start',
#   'day',
#   'pedro',
#   'pizarro',
#   'talk',
#   'plan',
#   'meet',
#   'goal',
#   'end',
#   'day',
#   'sec',
#   'join',
#   'friend',
#   'talk',
#   'cop',
#   'shop'],
#  ['militari',
#   'arm',
#   'compani',
#   'produc',
#   'carbon',
#   'emiss',
#   'individu',
#   'countri'],
#  ['look',
#   'world',
#   'amaz',
#   'sink',
#   'join',
#   'declar',
#   'forest',
#   'land',
#   'use',
#   'commit',
#   'halt',
#   'tackl',
#   'wildfir',
#   'help',
#   'restor',
#   'degrad',
#   'land',
#   'advanc',
#   'right',
#   'indigen',
#   'peopl',
#   'local',
#   'communiti',
#   'forest',
#   'countri'],
#  ['grato',
#   'aceptar',
#   'como',
#   'émica',
#   'del',
#   'educación',
#   'ambient',
#   'hacia',
#   'una',
#   'cultura',
#   'ecoeficiencia',
#   'uhnev',
#   'temática',
#   'para',
#   'las',
#   'dentro',
#   'del',
#   'marco'],
#  ['afghanistan',
#   'peopl',
#   'need',
#   'feminin',
#   'afghanistan',
#   'world',
#   'watch',
#   'interven',
#   'atroc',
#   'unfold',
#   'gasp'],
#  ['sampla',
#   'blo',
#   'displa',
#   'tourist',
#   'save',
#   'sem',
#   'kain',
#   'olsem',
#   'nogut',
#   'kam',
#   'nogat',
#   'san',
#   'lukim',
#   'trust',
#   'command',
#   'play',
#   'yupla',
#   'redi',
#   'klin',
#   'nau'],
#  ['glasgow',
#   'bin',
#   'strike',
#   'picket',
#   'dawsholm',
#   'western',
#   'show',
#   'solidar'],
#  ['come',
#   'glasgow',
#   'global',
#   'ambit',
#   'save',
#   'planet',
#   'peopl',
#   'gap',
#   'mitig',
#   'climat',
#   'pledg',
#   'need',
#   'degre',
#   'death',
#   'sentenc',
#   'want',
#   'dread',
#   'death',
#   'sentenc',
#   'come',
#   'today',
#   'tri',
#   'harder'],
#  ['stabil', 'depend', 'break'],
#  ['absolut',
#   'laughabl',
#   'airport',
#   'green',
#   'despit',
#   'like',
#   'let',
#   'forget',
#   'want',
#   'open',
#   'filthi',
#   'high',
#   'pollut',
#   'air',
#   'cargo',
#   'hub'],
#  ['coalit',
#   'ralli',
#   'birmingham',
#   'tell',
#   'politician',
#   'need',
#   'tackl',
#   'eastsid',
#   'citi',
#   'garden',
#   'millennium',
#   'point',
#   'birmingham',
#   'saturday',
#   'novemb',
#   'midday'],
#  ['declar', 'joke'],
#  ['stabil', 'depend', 'break'],
#  ['midnight',
#   'tought',
#   'countri',
#   'decid',
#   'limit',
#   'clear',
#   'forest',
#   'area',
#   'littl',
#   'late',
#   'question',
#   'reach',
#   'target',
#   'think',
#   'decis'],
#  ['power',
#   'need',
#   'speech',
#   'prime',
#   'minist',
#   'mia',
#   'mottley',
#   'want',
#   'exist',
#   'year',
#   'need',
#   'surviv'],
#  ['odd', 'cop', 'inclus'],
#  ['reduc',
#   'co₂',
#   'intak',
#   'unesco',
#   'caution',
#   'ocean',
#   'risk',
#   'lose',
#   'abil',
#   'absorb',
#   'carbon',
#   'exacerb',
#   'global',
#   'warm'],
#  ['nan'],
#  ['esg',
#   'environment',
#   'social',
#   'govern',
#   'framework',
#   'look',
#   'behaviour',
#   'invest',
#   'sustain',
#   'len',
#   'billion',
#   'dollar',
#   'shift',
#   'fossil',
#   'fuel',
#   'soon',
#   'trillion',
#   'privat',
#   'industri',
#   'move',
#   'faster',
#   'climat',
#   'chang',
#   'govern'],
#  ['gee', 'way', 'superspread', 'event'],
#  ['energ',
#   'meet',
#   'bold',
#   'commit',
#   'week',
#   'white',
#   'hous',
#   'conven',
#   'high',
#   'level',
#   'interag',
#   'ocean',
#   'polici',
#   'committe',
#   'work',
#   'close',
#   'colleagu',
#   'ensur',
#   'achiev',
#   'cop',
#   'announc'],
#  ['coo',
#   'nicol',
#   'kuepper',
#   'russel',
#   'partner',
#   'solar',
#   'technolog',
#   'innov',
#   'particip',
#   'panel',
#   'host',
#   'australian',
#   'renew',
#   'energi',
#   'agenc',
#   'emiss',
#   'solut',
#   'learn',
#   'ae'],
#  ['pittsburgh',
#   'yes',
#   'biggest',
#   'clean',
#   'energi',
#   'event',
#   'place',
#   'excit',
#   'announc',
#   'host',
#   'great',
#   'citi'],
#  ['problem',
#   'sprawl',
#   'bureaucrat',
#   'govt',
#   'minist',
#   'behold',
#   'group',
#   'undercut',
#   'environ',
#   'minist',
#   'walk',
#   'jakarta',
#   'pledg',
#   'end',
#   'deforest'],
#  ['generat',
#   'know',
#   'climat',
#   'chang',
#   'atmospher',
#   'deep',
#   'ocean',
#   'go',
#   'soon',
#   'cup'],
#  ['press',
#   'releas',
#   'link',
#   'record',
#   'press',
#   'confer',
#   'list',
#   'offici',
#   'websit'],
#  ['canada', 'end', 'financ', 'fossil', 'fuel', 'project', 'start'],
#  ['thank',
#   'interview',
#   'caitlin',
#   'doyl',
#   'markwick',
#   'sydney',
#   'protest',
#   'global',
#   'day',
#   'action',
#   'climat',
#   'justic',
#   'sit',
#   'nov',
#   'hyde',
#   'park',
#   'fountain',
#   'join'],
#  ['need',
#   'clear',
#   'vision',
#   'climat',
#   'educ',
#   'need',
#   'listen',
#   'thank',
#   'share',
#   'vision',
#   'climat',
#   'action',
#   'day'],
#  ['meet', 'johnni', 'dabrowski', 'give', 'youth', 'compil', 'chang', 'envis'],
#  ['selkirk',
#   'emiss',
#   'come',
#   'car',
#   'truck',
#   'mix',
#   'carbon',
#   'free',
#   'transport',
#   'solut',
#   'pursu',
#   'lower',
#   'emiss',
#   'introduc',
#   'selkirk',
#   'activ',
#   'transport',
#   'strategi'],
#  ['badg',
#   'check',
#   'observ',
#   'badg',
#   'come',
#   'hear',
#   'secur',
#   'guard',
#   'tri',
#   'enter',
#   'session',
#   'presid',
#   'open',
#   'dialogu',
#   'parti',
#   'observ',
#   'blue',
#   'zone',
#   'action',
#   'hub',
#   'hard',
#   'disagre'],
#  ['offshor',
#   'wind',
#   'industri',
#   'startup',
#   'industri',
#   'rule',
#   'startup',
#   'cake',
#   'get',
#   'big',
#   'cake'],
#  ['follow', 'news'],
#  ['great',
#   'speech',
#   'new',
#   'generat',
#   'stop',
#   'talk',
#   'start',
#   'need',
#   'new',
#   'vision',
#   'new',
#   'futur',
#   'vinisha',
#   'umashankar',
#   'world',
#   'leader',
#   'summit',
#   'contribut'],
#  ['nan'],
#  ['enjoy',
#   'session',
#   'student',
#   'explor',
#   'intervent',
#   'garden',
#   'inspir',
#   'generat'],
#  ['new',
#   'opportun',
#   'vision',
#   'engin',
#   'aquabyt',
#   'san',
#   'francisco',
#   'unit',
#   'state',
#   'appli'],
#  ['peopl',
#   'make',
#   'decis',
#   'save',
#   'natur',
#   'world',
#   'climat',
#   'rich',
#   'destroy',
#   'natur',
#   'world',
#   'measur',
#   'save',
#   'natur',
#   'world',
#   'climat',
#   'threaten',
#   'profit',
#   'independ',
#   'decis',
#   'maker'],
#  ['carolin', 'luca', 'speak', 'green', 'economi'],
#  ['david',
#   'attenborough',
#   'gem',
#   'chanc',
#   'keep',
#   'degre',
#   'global',
#   'warm',
#   'need',
#   'valu',
#   'servic',
#   'healthi',
#   'forest',
#   'provid'],
#  ['day',
#   'spend',
#   'day',
#   'meet',
#   'mayor',
#   'governor',
#   'local',
#   'leader',
#   'lead',
#   'climat',
#   'action',
#   'block',
#   'block',
#   'communiti',
#   'communiti'],
#  ['yes',
#   'citi',
#   'snp',
#   'voter',
#   'get',
#   'tell',
#   'use',
#   'park',
#   'dark',
#   'go',
#   'extra',
#   'light',
#   'park'],
#  ['dominican',
#   'republ',
#   'glasgow',
#   'think',
#   'retweet',
#   'good',
#   'increas',
#   'number',
#   'indi',
#   'caus',
#   'hope',
#   'good',
#   'guy'],
#  ['non', 'bind', 'agreement', 'bullshit'],
#  ['entertain', 'illumin', 'view'],
#  ['address',
#   'educ',
#   'action',
#   'countri',
#   'maintain',
#   'climat',
#   'abus',
#   'charg',
#   'crime',
#   'human'],
#  ['money', 'money', 'money', 'buy', 'natur', 'work', 'way'],
#  ['know',
#   'job',
#   'get',
#   'gas',
#   'compani',
#   'sponsor',
#   'global',
#   'climat',
#   'action',
#   'summit',
#   'kind',
#   'like'],
#  ['rememb'],
#  ['possibl',
#   'divid',
#   'human',
#   'provid',
#   'essenti',
#   'global',
#   'public',
#   'good',
#   'jinp',
#   'leader',
#   'countri',
#   'largest',
#   'emiss',
#   'greenhous',
#   'gas',
#   'decid',
#   'attend',
#   'answer',
#   'encourag'],
#  ['critic',
#   'sustain',
#   'futur',
#   'largest',
#   'busi',
#   'opportun',
#   'time',
#   'say',
#   'rmi',
#   'read'],
#  ['impact',
#   'warm',
#   'climat',
#   'appar',
#   'sever',
#   'urg',
#   'world',
#   'leader',
#   'busi',
#   'aggress',
#   'climat',
#   'action'],
#  ['sir', 'david'],
#  ['psaki',
#   'white',
#   'hous',
#   'aid',
#   'travel',
#   'biden',
#   'test',
#   'posit',
#   'quarantin',
#   'scotland',
#   'bloomberg'],
#  ['issu', 'child', 'action'],
#  ['climat', 'commit', 'mean'],
#  ['interest',
#   'exampl',
#   'share',
#   'journey',
#   'carbon',
#   'net',
#   'zero',
#   'share',
#   'academi',
#   'commit',
#   'action',
#   'ambit',
#   'fascin',
#   'read'],
#  ['nan'],
#  ['denmark',
#   'indonesia',
#   'india',
#   'australia',
#   'invest',
#   'natur',
#   'help',
#   'communiti',
#   'adapt',
#   'reduc',
#   'disast',
#   'climat',
#   'risk'],
#  ['hope', 'news'],
#  ['gaiascop',
#   'step',
#   'build',
#   'brain',
#   'grid',
#   'activ',
#   'build',
#   'solut',
#   'climat',
#   'chang'],
#  ['histori',
#   'judg',
#   'microsoft',
#   'bad',
#   'opportun',
#   'empow',
#   'person',
#   'take',
#   'window',
#   'environment',
#   'catastroph',
#   'throw',
#   'away',
#   'pcs',
#   'trillion',
#   'dollar',
#   'org',
#   'tri',
#   'overcom',
#   'organis',
#   'aphantasia',
#   'environment',
#   'consequ'],
#  ['research',
#   'aim',
#   'amplifi',
#   'voic',
#   'understand',
#   'futur',
#   'quito',
#   'creat',
#   'opportun',
#   'children',
#   'act',
#   'share',
#   'understand'],
#  ['australia', 'track', 'morrison', 'way'],
#  ['action',
#   'need',
#   'action',
#   'climat',
#   'chang',
#   'act',
#   'need',
#   'prepar',
#   'impact',
#   'multipl',
#   'hazard',
#   'loudest',
#   'voic',
#   'action',
#   'youth',
#   'children',
#   'brilliant',
#   'earli',
#   'career',
#   'research'],
#  ['mass',
#   'near',
#   'road',
#   'greet',
#   'presid',
#   'félix',
#   'tshisekedi',
#   'sign',
#   'deep',
#   'love',
#   'popul',
#   'feel',
#   'leader',
#   'novemb',
#   'recept',
#   'drc',
#   'presid',
#   'popul',
#   'congoles',
#   'capit',
#   'kinshasa'],
#  ['clear',
#   'messag',
#   'climat',
#   'pledg',
#   'announc',
#   'date',
#   'meet',
#   'time',
#   'hold',
#   'rise',
#   'global',
#   'temperatur'],
#  ['icym',
#   'india',
#   'china',
#   'lesser',
#   'develop',
#   'develop',
#   'countri',
#   'usa',
#   'australia',
#   'capita',
#   'cumul',
#   'pollut',
#   'disgrac'],
#  ['hear',
#   'richard',
#   'levi',
#   'gns',
#   'environ',
#   'climat',
#   'leader',
#   'differ',
#   'moment',
#   'global',
#   'action',
#   'combat',
#   'climat',
#   'chang'],
#  ['australia',
#   'pavilion',
#   'slam',
#   'promot',
#   'fossil',
#   'fuel',
#   'compani',
#   'unasham',
#   'promot',
#   'fals',
#   'solut',
#   'bradshaw',
#   'say'],
#  ['pledg',
#   'glasgow',
#   'strong',
#   'countri',
#   'abil',
#   'deliv',
#   'write',
#   'muriel',
#   'macdonald'],
#  ['polar',
#   'albedo',
#   'better',
#   'understand',
#   'reason',
#   'arctic',
#   'amplifi',
#   'warm'],
#  ['press',
#   'confer',
#   'california',
#   'zero',
#   'get',
#   'american',
#   'state',
#   'net',
#   'zero',
#   'go'],
#  ['give',
#   'repres',
#   'ngo',
#   'call',
#   'tremenda',
#   'inspir',
#   'meet',
#   'one',
#   'drive',
#   'futur',
#   'better'],
#  ['day',
#   'confer',
#   'signal',
#   'pressur',
#   'decarbon',
#   'imo',
#   'beef',
#   'reduct',
#   'target'],
#  ['world',
#   'readi',
#   'forward',
#   'realiti',
#   'reduc',
#   'global',
#   'carbon',
#   'emiss',
#   'solut',
#   'frank',
#   'wolak',
#   'give',
#   'insight',
#   'read',
#   'stori',
#   'today'],
#  ['india',
#   'china',
#   'lesser',
#   'develop',
#   'develop',
#   'countri',
#   'usa',
#   'australia',
#   'capita',
#   'cumul',
#   'pollut',
#   'disgrac'],
#  ['dataviz', 'hashtag'],
#  ['homepag',
#   'featur',
#   'video',
#   'impass',
#   'speech',
#   'youth',
#   'climat',
#   'activist',
#   'kenya',
#   'elizabeth',
#   'wathuti',
#   'tell',
#   'world',
#   'leader',
#   'summit',
#   'cop',
#   'glasgow',
#   'open',
#   'heart'],
#  ['hrh', 'work', 'tireless', 'repres', 'feel', 'involv', 'engag', 'import'],
#  ['lgnn', 'kingdom', 'alt', 'see', 'time'],
#  ['loom',
#   'climat',
#   'crisi',
#   'go',
#   'covid',
#   'pandem',
#   'like',
#   'minor',
#   'hiccup',
#   'comparison',
#   'leader',
#   'prepar',
#   'wear',
#   'climat',
#   'mask',
#   'nose',
#   'stick'],
#  ['reason',
#   'concern',
#   'past',
#   'year',
#   'see',
#   'climat',
#   'chang',
#   'fuel',
#   'extrem',
#   'weather',
#   'rival',
#   'revel'],
#  ['daili', 'telegraph', 'pledg', 'ignor', 'tree', 'burn', 'electr'],
#  ['india',
#   'china',
#   'lesser',
#   'develop',
#   'develop',
#   'countri',
#   'usa',
#   'australia',
#   'capita',
#   'cumul',
#   'pollut',
#   'disgrac'],
#  ['ajang',
#   'unit',
#   'nation',
#   'climat',
#   'chang',
#   'confer',
#   'cop',
#   'glasgow',
#   'skotlandia'],
#  ['power',
#   'report',
#   'climat',
#   'energ',
#   'emerg',
#   'affect',
#   'real',
#   'peopl',
#   'live',
#   'need',
#   'hear',
#   'plea',
#   'answer',
#   'urgent',
#   'tangibl',
#   'action'],
#  ['biden',
#   'lift',
#   'trudeau',
#   'serious',
#   'think',
#   'miss',
#   'good',
#   'opportun',
#   'lead',
#   'exampl',
#   'especi',
#   'amlo',
#   'mexico',
#   'say',
#   'basta',
#   'hipocresía',
#   'logist',
#   'simpl'],
#  ['nan'],
#  ['thursday',
#   'wear',
#   'green',
#   'align',
#   'demand',
#   'transit',
#   'regen',
#   'care',
#   'center',
#   'economi',
#   'center',
#   'action'],
#  ['live', 'climat', 'summit', 'focus', 'energi', 'transit'],
#  ['today',
#   'opportun',
#   'speak',
#   'get',
#   'california',
#   'highlight',
#   'california',
#   'leadership',
#   'proud',
#   'note',
#   'california',
#   'reduc',
#   'emiss',
#   'capita',
#   'time',
#   'grow',
#   'economi'],
#  ['bombard',
#   'depress',
#   'news',
#   'day',
#   'land',
#   'tonight',
#   'time',
#   'laugh',
#   'politician',
#   'hilari',
#   'remark',
#   'climat',
#   'crisi',
#   'great',
#   'stuff',
#   'enjoy',
#   'singl',
#   'moment'],
#  ['big',
#   'weekend',
#   'march',
#   'glasgow',
#   'weekend',
#   'midpoint',
#   'youth',
#   'tomorrow',
#   'rest',
#   'movement',
#   'saturday',
#   'go',
#   'interest',
#   'day'],
#  ['brian', 'crombi', 'hour', 'greg', 'vezina', 'youtub', 'nov'],
#  ['stark', 'visual', 'remind', 'long', 'way'],
#  ['total',
#   'unaccept',
#   'negoti',
#   'continu',
#   'africa',
#   'contribut',
#   'global',
#   'ghg',
#   'emiss',
#   'pollut',
#   'countri',
#   'respons',
#   'emiss'],
#  ['australia',
#   'join',
#   'china',
#   'russia',
#   'india',
#   'iran',
#   'biggest',
#   'methan',
#   'emitt',
#   'refus',
#   'join',
#   'global',
#   'push'],
#  ['interest', 'statement'],
#  ['scotland',
#   'separ',
#   'mind',
#   'run',
#   'separatist',
#   'polit',
#   'parti',
#   'play',
#   'host',
#   'world',
#   'leader',
#   'climat',
#   'chang',
#   'summit',
#   'nation',
#   'desir',
#   'exit',
#   'union',
#   'nation',
#   'fulli',
#   'determin',
#   'destini',
#   'demon'],
#  ['say',
#   'emili',
#   'thornberri',
#   'proper',
#   'insul',
#   'home',
#   'crucial',
#   'govern',
#   'help',
#   'recent',
#   'year'],
#  ['head', 'glasgow'],
#  ['devot', 'week', 'odd', 'programm', 'urgent', 'problem', 'human', 'face'],
#  ['earth',
#   'warm',
#   'ice',
#   'car',
#   'windscreen',
#   'insid',
#   'week',
#   'novemb',
#   'metereolog',
#   'autumn'],
#  ['know', 'piss', 'critic', 'help', 'planet'],
#  ['해시를', '하이브굿즈'],
#  ['technolog', 'dump', 'oil', 'forev', 'ocean', 'wave', 'solut', 'implement'],
#  ['check', 'cop', 'live'],
#  ['absolut'],
#  ['love', 'see', 'activ'],
#  ['rais', 'price'],
#  ['news',
#   'make',
#   'clear',
#   'enorm',
#   'chang',
#   'come',
#   'manag',
#   'difficult',
#   'half',
#   'world',
#   'fossil',
#   'fuel',
#   'asset',
#   'worthless',
#   'net',
#   'zero',
#   'transit'],
#  ['ceo',
#   'say',
#   'compani',
#   'stop',
#   'compet',
#   'start',
#   'cooper',
#   'honest',
#   'smile',
#   'remind',
#   'call',
#   'reform',
#   'capit',
#   'democrat',
#   'control'],
#  ['beth', 'love', 'chat', 'briefli', 'communic', 'work'],
#  ['valu'],
#  ['join',
#   'nov',
#   'great',
#   'panellist',
#   'palmer',
#   'ceo',
#   'amo',
#   'dir',
#   'tedxplattsburgh',
#   'free',
#   'ticket'],
#  ['pln'],
#  ['jot', 'aviat', 'kingdom', 'alt', 'see', 'time'],
#  ['mckibben', 'need', 'fast', 'glasgow', 'non', 'prolifer', 'parti'],
#  ['justin',
#   'trudeau',
#   'world',
#   'leader',
#   'come',
#   'wast',
#   'money',
#   'virtu',
#   'signal'],
#  ['pictur',
#   'creativ',
#   'produc',
#   'adrien',
#   'jenik',
#   'meet',
#   'xavier',
#   'cortada',
#   'xavier',
#   'project',
#   'call',
#   'hello',
#   'elev',
#   'check'],
#  ['open', 'letter', 'nichola', 'sturgeon'],
#  ['disgrac'],
#  ['spell', 'make', 'sens', 'govern'],
#  ['methan', 'huge', 'emiss', 'problem', 'add', 'multipl', 'solut', 'need'],
#  ['final',
#   'award',
#   'race',
#   'disast',
#   'loan',
#   'money',
#   'fossil',
#   'fuel',
#   'industri',
#   'bank',
#   'year',
#   'lead',
#   'start',
#   'climat',
#   'talk'],
#  ['know', 'miss', 'best', 'unquestion'],
#  ['daili',
#   'twitter',
#   'wordcloud',
#   'scottish',
#   'politician',
#   'novemb',
#   'total',
#   'tweet',
#   'tweet',
#   'tweet',
#   'highest',
#   'like',
#   'like',
#   'tag'],
#  ['dismiss', 'brush', 'articul', 'heartfelt', 'plea', 'make', 'sad', 'angri'],
#  ['put', 'stamp', 'natur', 'day', 'commit', 'sunset', 'coal'],
#  ['current',
#   'govern',
#   'sensibl',
#   'coher',
#   'grow',
#   'actual',
#   'mean',
#   'like',
#   'transitori',
#   'parad',
#   'bluster'],
#  ['faq', 'race', 'zero', 'sgk', 'planet'],
#  ['play',
#   'outsiz',
#   'role',
#   'worsen',
#   'climat',
#   'crisi',
#   'continu',
#   'action',
#   'fight',
#   'collabor',
#   'monica',
#   'cruz',
#   'write'],
#  ['forum', 'cop', 'live'],
#  ['canadian',
#   'politician',
#   'commit',
#   'reduc',
#   'carbon',
#   'footprint',
#   'signific',
#   'reduc',
#   'flight',
#   'time',
#   'zoom',
#   'lead',
#   'exampl',
#   'watch',
#   'close'],
#  ['polici', 'contradict', 'magic', 'think'],
#  ['leader',
#   'climat',
#   'chang',
#   'topic',
#   'global',
#   'agenda',
#   'turn',
#   'complet',
#   'utter',
#   'leader',
#   'blast',
#   'fuel',
#   'attend',
#   'big',
#   'fish',
#   'moni',
#   'deal',
#   'mess',
#   'sky'],
#  ['frustrat',
#   'tire',
#   'see',
#   'old',
#   'doom',
#   'gloom',
#   'headlin',
#   'time',
#   'organ',
#   'chang',
#   'want',
#   'join',
#   'set',
#   'platform',
#   'folk',
#   'meet',
#   'network',
#   'idea',
#   'meet',
#   'kindr',
#   'spirit'],
#  ['covid', 'opportunist', 'propag', 'event'],
#  ['greta', 'thunberg', 'storm', 'panel', 'blast', 'greenwash', 'festiv'],
#  ['pleas',
#   'discuss',
#   'good',
#   'news',
#   'pathway',
#   'degre',
#   'warm',
#   'accord',
#   'bring',
#   'closer',
#   'goal'],
#  ['spoiler', 'alert', 'govern', 'rat', 'ars', 'environ'],
#  ['biden',
#   'apolog',
#   'glasgow',
#   'show',
#   'hypocrisi',
#   'powerless',
#   'politician'],
#  ['hope', 'agenda', 'glasgow'],
#  ['hypocrit', 'deleg', 'serv', 'dairi', 'despit', 'reduc', 'intak'],
#  ['price', 'sew', 'wast'],
#  ['nan'],
#  ['join',
#   'tomorrow',
#   'special',
#   'focus',
#   'start',
#   'aet',
#   'gmt',
#   'friday',
#   'nov',
#   'learn',
#   'ocean',
#   'central',
#   'mitig',
#   'adapt'],
#  ['meet', 'leader', 'connect', 'explor', 'work', 'negat', 'inaugur', 'report'],
#  ['govern',
#   'report',
#   'say',
#   'hunki',
#   'dori',
#   'news',
#   'report',
#   'say',
#   'gbr',
#   'threat',
#   'warm',
#   'sea',
#   'account',
#   'season',
#   'fluctuat',
#   'long',
#   'term',
#   'threat',
#   'human',
#   'activ',
#   'warm',
#   'overwhelm',
#   'esp'],
#  ['explor',
#   'commit',
#   'expect',
#   'role',
#   'asx',
#   'tym',
#   'play',
#   'futur',
#   'net',
#   'zero'],
#  ['great',
#   'barrier',
#   'reef',
#   'bleach',
#   'affect',
#   'cent',
#   'coral',
#   'ecosystem',
#   'demand'],
#  ['hehe',
#   'listen',
#   'corbynista',
#   'tim',
#   'stanley',
#   'tori',
#   'quick',
#   'labour',
#   'manifesto',
#   'centr',
#   'tackl',
#   'climat',
#   'chang'],
#  ['john',
#   'kerri',
#   'glasgow',
#   'climat',
#   'summit',
#   'achiev',
#   'success',
#   'time',
#   'run',
#   'short'],
#  ['nan'],
#  ['meet', 'leader', 'connect', 'explor', 'work', 'negat', 'inaugur', 'report'],
#  ['good', 'project'],
#  ['school',
#   'colleg',
#   'work',
#   'hard',
#   'tackl',
#   'climat',
#   'chang',
#   'look',
#   'environ',
#   'practic',
#   'measur',
#   'activ',
#   'educ',
#   'reflect',
#   'depth',
#   'feel',
#   'pupil',
#   'crucial',
#   'topic',
#   'comment',
#   'climat',
#   'educ'],
#  ['india',
#   'china',
#   'lesser',
#   'develop',
#   'develop',
#   'countri',
#   'usa',
#   'australia',
#   'capita',
#   'cumul',
#   'pollut',
#   'disgrac'],
#  ['world', 'watch', 'impact', 'speech', 'million', 'watch'],
#  ['buy', 'place', 'provid', 'charg', 'home', 'safe', 'hope', 'listen'],
#  ['dear',
#   'realiz',
#   'australia',
#   'net',
#   'zero',
#   'commit',
#   'clayton',
#   'commit',
#   'fantasi',
#   'world',
#   'probabl',
#   'think',
#   'meaning',
#   'planet'],
#  ['countri', 'commit', 'stop', 'deforest', 'malaysia'],
#  ['good',
#   'initi',
#   'give',
#   'infrastructur',
#   'support',
#   'action',
#   'best',
#   'way',
#   'teach',
#   'understand',
#   'respect',
#   'precious',
#   'resourc',
#   'faucet',
#   'harvest',
#   'toilet',
#   'convert',
#   'foodwast',
#   'fuel',
#   'liquid',
#   'compost'],
#  ['global', 'north', 'greenwash', 'festiv'],
#  ['citi',
#   'world',
#   'step',
#   'set',
#   'bold',
#   'target',
#   'delug',
#   'action',
#   'bring',
#   'emiss',
#   'proud',
#   'work',
#   'continu',
#   'lead',
#   'respond'],
#  ['precis',
#   'think',
#   'peep',
#   'pictur',
#   'inch',
#   'away',
#   'throw',
#   'jail',
#   'fast',
#   'forward',
#   'mega',
#   'billionair',
#   'think',
#   'compromis',
#   'train',
#   'like',
#   'offer',
#   'refus'],
#  ['brazil',
#   'acr',
#   'river',
#   'reach',
#   'lowest',
#   'level',
#   'drought',
#   'flood',
#   'watch',
#   'video'],
#  ['ultim',
#   'thing',
#   'help',
#   'mental',
#   'physic',
#   'safeti',
#   'age',
#   'group',
#   'includ',
#   'young',
#   'meaning',
#   'action',
#   'world',
#   'leader'],
#  ['miss',
#   'fascin',
#   'discuss',
#   'lead',
#   'pres',
#   'lauri',
#   'wayburn',
#   'live',
#   'pft',
#   'board',
#   'member',
#   'emin',
#   'forest',
#   'ecologist',
#   'jerri',
#   'franklin',
#   'intern',
#   'forest',
#   'carbon',
#   'expert',
#   'andrea',
#   'tuttl',
#   'regist'],
#  ['believ',
#   'shell',
#   'think',
#   'zero',
#   'shape',
#   'forest',
#   'climat',
#   'action',
#   'shell',
#   'think',
#   'carbon',
#   'offset',
#   'address',
#   'climat',
#   'crisi',
#   'big',
#   'hole',
#   'middl',
#   'argument',
#   'bewar'],
#  ['join',
#   'new',
#   'platform',
#   'spur',
#   'growth',
#   'low',
#   'carbon',
#   'technolog',
#   'count',
#   'engi',
#   'found',
#   'member',
#   'compani',
#   'commit',
#   'purchas',
#   'zero',
#   'emiss',
#   'good',
#   'servic',
#   'step',
#   'closer',
#   'net',
#   'zero',
#   'carbon',
#   'futur'],
#  ['canada', 'send', 'deleg', 'cop', 'let', 'sink'],
#  ['suppos',
#   'bring',
#   'chang',
#   'usual',
#   'capitalist',
#   'structur',
#   'major',
#   'white',
#   'men',
#   'inforc',
#   'mean',
#   'lead',
#   'joke',
#   'need',
#   'radic',
#   'chang',
#   'divers',
#   'group',
#   'repres',
#   'futur',
#   'indigen',
#   'land',
#   'right',
#   'respect',
#   'save',
#   'planet'],
#  ['california',
#   'stake',
#   'high',
#   'doubl',
#   'fail',
#   'polici',
#   'need',
#   'new',
#   'framework',
#   'generat',
#   'real',
#   'result',
#   'hold',
#   'pollut',
#   'account',
#   'direct',
#   'measur',
#   'emiss',
#   'reduct',
#   'sourc'],
#  ['name',
#   'exclud',
#   'cop',
#   'longer',
#   'climat',
#   'confer',
#   'global',
#   'north',
#   'greenwash',
#   'festiv',
#   'week',
#   'celebr',
#   'busi',
#   'usual',
#   'blah',
#   'blah',
#   'blah'],
#  ['outsid',
#   'even',
#   'address',
#   'fund',
#   'loss',
#   'damag',
#   'global',
#   'north',
#   'caus',
#   'global',
#   'south'],
#  ['need',
#   'transit',
#   'pollut',
#   'renew',
#   'energi',
#   'thursday',
#   'energi',
#   'day',
#   'climat',
#   'confer',
#   'watch',
#   'expert',
#   'discuss',
#   'import',
#   'achiev',
#   'sustain',
#   'energi',
#   'futur'],
#  ['apt', 'go'],
#  ['pointok', 'sweet', 'photo'],
#  ['nan'],
#  ['join',
#   'new',
#   'platform',
#   'spur',
#   'growth',
#   'low',
#   'carbon',
#   'technolog',
#   'count',
#   'engi',
#   'found',
#   'member',
#   'compani',
#   'commit',
#   'purchas',
#   'zero',
#   'emiss',
#   'good',
#   'servic',
#   'step',
#   'closer',
#   'net',
#   'zero',
#   'carbon',
#   'futur'],
#  ['friday', 'rememb', 'recit', 'durood', 'today', 'learn', 'ローソンもちもちどらもっち'],
#  ['come', 'reuter'],
#  ['come', 'health', 'hazard', 'cost', 'health', 'environ', 'depend', 'surviv'],
#  ['go', 'china', 'carbon', 'emiss'],
#  ['check',
#   'import',
#   'climat',
#   'insight',
#   'solut',
#   'survey',
#   'key',
#   'find',
#   'new',
#   'technolog',
#   'overwhelm',
#   'thing',
#   'make',
#   'peopl',
#   'feel',
#   'hope'],
#  ['man', 'talk', 'think', 'mean'],
#  ['natur', 'remind', 'night', 'fight', 'mile', 'west', 'glasgow'],
#  ['definit',
#   'worth',
#   'watch',
#   'break',
#   'boundari',
#   'scienc',
#   'planet',
#   'netflix'],
#  ['air',
#   'pollut',
#   'sit',
#   'intersect',
#   'critic',
#   'issu',
#   'climat',
#   'chang',
#   'public',
#   'health',
#   'learn',
#   'bloomberg',
#   'bloomberg',
#   'philanthropi',
#   'launch',
#   'ambiti',
#   'clean',
#   'air',
#   'effort'],
#  ['miss',
#   'seem',
#   'good',
#   'news',
#   'bylin',
#   'nugget',
# ...
#   'report'],
#  ['great',
#   'compani',
#   'drink',
#   'food',
#   'scholar',
#   'alumni',
#   'long',
#   'day',
#   'good',
#   'reminisc',
#   'memori',
#   'believ',
#   'go',
#   'use',
#   'hashtag',
#   'thank',
#   'organis'],
#  ['proud',
#   'organ',
#   'committe',
#   'today',
#   'ralli',
#   'argu',
#   'militari',
#   'emiss',
#   'longer',
#   'exclud',
#   'climat',
#   'agreement'],
#  ['hopeless', 'like', 'need', 'buy', 'diesel', 'save', 'planet', 'load'],
#  ['meer',
#   'type',
#   'scheme',
#   'region',
#   'citi',
#   'level',
#   'roll',
#   'relat',
#   'quick',
#   'larger',
#   'global',
#   'scheme',
#   'depend',
#   'type',
#   'consensus',
#   'reach',
#   'exact',
#   'inspir',
#   'confid'],
#  ['countri', 'corrupt', 'big', 'busi'],
#  ['tori', 'go', 'break', 'bollock', 'price'],
#  ['compani',
#   'promis',
#   'net',
#   'zero',
#   'emiss',
#   'histori',
#   'deceiv',
#   'sharehold',
#   'govern'],
#  ['worth', 'attend', 'week'],
#  ['start',
#   'watch',
#   'hop',
#   'listen',
#   'insight',
#   'question',
#   'tori',
#   'sleaz',
#   'turn',
#   'decid',
#   'read',
#   'instead'],
#  ['need',
#   'remind',
#   'peopl',
#   'collect',
#   'action',
#   'differ',
#   'drop',
#   'bucket',
#   'professor',
#   'ben',
#   'newel',
#   'school',
#   'psycholog',
#   'persuad',
#   'individu',
#   'tackl'],
#  ['entir',
#   'mangrov',
#   'ecosystem',
#   'destroy',
#   'papuan',
#   'coastal',
#   'communiti',
#   'lead',
#   'soil',
#   'eros',
#   'unhealthi',
#   'fisheri',
#   'equip',
#   'inform',
#   'languag',
#   'communiti',
#   'restor',
#   'near',
#   'acr'],
#  ['nan'],
#  ['spot', 'failur'],
#  ['privat',
#   'aircraft',
#   'tonn',
#   'approx',
#   'million',
#   'carbon',
#   'dioxid',
#   'flight',
#   'climat',
#   'chang',
#   'confer',
#   'hypocrisi',
#   'whatsoev',
#   'shut',
#   'peasant',
#   'hancock'],
#  ['worth',
#   'worth',
#   'avoid',
#   'forev',
#   'sustain',
#   'stop',
#   'abus',
#   'chanc',
#   'fight',
#   'wallet'],
#  ['partnership',
#   'lead',
#   'creation',
#   'bioeconomi',
#   'fund',
#   'includ',
#   'invest',
#   'fund',
#   'million',
#   'strengthen',
#   'amazon',
#   'bioeconomi',
#   'preserv',
#   'natur',
#   'capit'],
#  ['pay',
#   'attent',
#   'see',
#   'film',
#   'know',
#   'end',
#   'disappoint',
#   'urgent',
#   'need',
#   'rapid',
#   'massiv',
#   'scale',
#   'chang',
#   'avert',
#   'disast',
#   'current',
#   'need',
#   'new'],
#  ['campaign',
#   'want',
#   'illustr',
#   'way',
#   'nuanc',
#   'intersect',
#   'approach',
#   'climat',
#   'justic',
#   'peacebuild',
#   'essenti',
#   'order',
#   'creat',
#   'sustain',
#   'world'],
#  ['polic',
#   'respons',
#   'complet',
#   'arrest',
#   'peopl',
#   'planet',
#   'futur',
#   'let',
#   'climat',
#   'crimin',
#   'rock',
#   'helicopt',
#   'privat',
#   'plan',
#   'motorcad',
#   'polic',
#   'shame'],
#  ['join',
#   'novemb',
#   'introduc',
#   'pathway',
#   'lab',
#   'univers',
#   'equit',
#   'coverag',
#   'open',
#   'access',
#   'big',
#   'data',
#   'inform',
#   'inform',
#   'resili',
#   'lab'],
#  ['health',
#   'care',
#   'harm',
#   'latin',
#   'america',
#   'climat',
#   'lead',
#   'share',
#   'highlight',
#   'futur',
#   'lab',
#   'climat',
#   'smart',
#   'healthcar',
#   'healthier',
#   'planet',
#   'event',
#   'spanish',
#   'speaker',
#   'miss',
#   'tweet',
#   'updat',
#   'key',
#   'moment'],
#  ['big', 'hoax', 'creat', 'better', 'world'],
#  ['say',
#   'speech',
#   'australia',
#   'emiss',
#   'fall',
#   'far',
#   'exceed',
#   'pari',
#   'commit'],
#  ['susana',
#   'master',
#   'politician',
#   'businessmen',
#   'fuck',
#   'effort',
#   'climat',
#   'chang'],
#  ['use', 'sustain', 'caus', 'best', 'chanc', 'wallet'],
#  ['learn',
#   'serious',
#   'climat',
#   'chang',
#   'express',
#   'poetri',
#   'fantast',
#   'effort'],
#  ['updat', 'week', 'list', 'news', 'link'],
#  ['word',
#   'great',
#   'friend',
#   'cop',
#   'massiv',
#   'piss',
#   'tax',
#   'payer',
#   'expens'],
#  ['fiji', 'particip', 'indo', 'pacif', 'carbon', 'offset', 'scheme', 'launch'],
#  ['win', 'leagu', 'great', 'go', 'tell', 'good', 'environ'],
#  ['person', 'give', 'hope'],
#  ['time',
#   'group',
#   'activist',
#   'blockad',
#   'edinburgh',
#   'offic',
#   'bring',
#   'welcom',
#   'global',
#   'solidar',
#   'campaign',
#   'climat',
#   'chao'],
#  ['buy', 'product', 'despit', 'sustain', 'caus', 'abus'],
#  ['strong', 'resili', 'round', 'natur', 'disast', 'showcas', 'intern', 'stag'],
#  ['fascin',
#   'discuss',
#   'green',
#   'zone',
#   'afternoon',
#   'renew',
#   'energi',
#   'project',
#   'work',
#   'alongsid',
#   'indigen',
#   'peopl',
#   'repres',
#   'new',
#   'form',
#   'energi',
#   'coloni'],
#  ['pic',
#   'rile',
#   'bojo',
#   'angela',
#   'merkel',
#   'nicola',
#   'sturgeon',
#   'great',
#   'european',
#   'leader'],
#  ['piss',
#   'climat',
#   'chang',
#   'denier',
#   'thing',
#   'see',
#   'peopl',
#   'right',
#   'scrutin',
#   'inact',
#   'prior',
#   'declar',
#   'want',
#   'ensur',
#   'semblanc',
#   'account',
#   'leader',
#   'platitud'],
#  ['swing',
#   'effort',
#   'creat',
#   'greener',
#   'futur',
#   'get',
#   'start',
#   'step',
#   'take',
#   'promot',
#   'sustain',
#   'fight',
#   'climat',
#   'chang'],
#  ['nan'],
#  ['imagin',
#   'number',
#   'peool',
#   'quarantin',
#   'need',
#   'quarantin',
#   'unfit',
#   'run',
#   'countri',
#   'think',
#   'let'],
#  ['takeaway',
#   'day',
#   'degre',
#   'reach',
#   'deal',
#   'coal',
#   'activist',
#   'request',
#   'fewer',
#   'polic'],
#  ['think', 'bubbl', 'talk', 'eff', 'wanker'],
#  ['thing',
#   'motorsport',
#   'play',
#   'role',
#   'cleaner',
#   'mobil',
#   'think',
#   'impress',
#   'fact',
#   'pretti',
#   'run',
#   'fuel',
#   'wine',
#   'man',
#   'year'],
#  ['live', 'discuss', 'world', 'path', 'forward', 'fight', 'climat', 'chang'],
#  ['tragic', 'happen', 'know', 'stop'],
#  ['photo', 'opp', 'briefcas'],
#  ['break',
#   'global',
#   'econom',
#   'transit',
#   'highlight',
#   'trillion',
#   'alloc',
#   'countri',
#   'sign',
#   'reduct',
#   'pledg',
#   'conserv',
#   'pledg',
#   'sign',
#   'cover',
#   'fairest',
#   'land'],
#  ['new', 'face', 'movi', 'take', 'mama'],
#  ['big', 'hoax', 'creat', 'better', 'world'],
#  ['good', 'word', 'paul'],
#  ['biden', 'jesuit', 'communist', 'go', 'disast'],
#  ['skeptic',
#   'mock',
#   'horror',
#   'take',
#   'privat',
#   'jet',
#   'climat',
#   'confer',
#   'let',
#   'bluff',
#   'sort',
#   'climat',
#   'chang',
#   'hypocrisi'],
#  ['finger', 'cross', 'time', 'commit', 'back', 'action'],
#  ['nan'],
#  ['minor',
#   'tech',
#   'failur',
#   'good',
#   'near',
#   'destroy',
#   'misplac',
#   'tug',
#   'microphon',
#   'good',
#   'panel',
#   'financ',
#   'support',
#   'net',
#   'zero'],
#  ['cusson',
#   'carex',
#   'imperi',
#   'leather',
#   'morn',
#   'fresh',
#   'use',
#   'sustain',
#   'caus',
#   'wallet'],
#  ['interest',
#   'den',
#   'enjoy',
#   'nice',
#   'food',
#   'celebr',
#   'big',
#   'win',
#   'light',
#   'bring',
#   'famili'],
#  ['nan'],
#  ['need',
#   'energi',
#   'late',
#   'night',
#   'negoti',
#   'import',
#   'focus',
#   'detail',
#   'emiss',
#   'baselin',
#   'set'],
#  ['watch',
#   'trick',
#   'bbc',
#   'iplay',
#   'wonder',
#   'nigel',
#   'lawson',
#   'get',
#   'minut',
#   'slot',
#   'today',
#   'programm',
#   'week',
#   'propag',
#   'view',
#   'climat',
#   'chang',
#   'think',
#   'tori',
#   'new'],
#  ['congratul',
#   'partner',
#   'samso',
#   'energi',
#   'academi',
#   'denmark',
#   'honor',
#   'special',
#   'anniversari',
#   'edit',
#   'unit',
#   'nation',
#   'global',
#   'climat',
#   'action',
#   'award'],
#  ['look', 'like', 'shun', 'cop', 'persona', 'non', 'grata'],
#  ['scottish', 'train', 'middl', 'drunken', 'teenag', 'teas', 'boomer'],
#  ['need',
#   'scheme',
#   'alongsid',
#   'increas',
#   'rid',
#   'pollut',
#   'vehicl',
#   'start',
#   'reduc',
#   'improv',
#   'lot',
#   'win'],
#  ['namast',
#   'unrol',
#   'financ',
#   'day',
#   'time',
#   'fulfil',
#   'old',
#   'promis',
#   'soon'],
#  ['buy',
#   'food',
#   'farmer',
#   'like',
#   'rest',
#   'assur',
#   'support',
#   'industri',
#   'commit',
#   'net',
#   'zero'],
#  ['proud',
#   'take',
#   'action',
#   'combat',
#   'climat',
#   'chang',
#   'point',
#   'plan',
#   'achiev',
#   'ambit',
#   'social',
#   'enterpris',
#   'take',
#   'lead',
#   'tackl',
#   'climat',
#   'chang'],
#  ['look',
#   'forward',
#   'beam',
#   'tomorrow',
#   'morn',
#   'assembl',
#   'flashback',
#   'assembl',
#   'team',
#   'zoom'],
#  ['latin', 'america', 'unveil', 'new', 'climat', 'commit', 'read'],
#  ['address',
#   'need',
#   'develop',
#   'countri',
#   'vulner',
#   'damag',
#   'caus',
#   'think',
#   'vital',
#   'leader',
#   'creat',
#   'commit',
#   'address',
#   'climat',
#   'chang',
#   'climat',
#   'negoti',
#   'glasgow'],
#  ['nan'],
#  ['delight',
#   'join',
#   'green',
#   'mosqu',
#   'event',
#   'key',
#   'note',
#   'speaker',
#   'pioneer',
#   'initi',
#   'mosqu',
#   'lead',
#   'way',
#   'greener',
#   'communiti',
#   'excel',
#   'even',
#   'compani',
#   'final',
#   'get',
#   'pic'],
#  ['die',
#   'erklärung',
#   'des',
#   'ersten',
#   'globalen',
#   'klima',
#   'bürgerrat',
#   'globalassembl',
#   'peopl',
#   'declar',
#   'sustain',
#   'futur',
#   'planet',
#   'earth'],
#  ['help',
#   'promot',
#   'project',
#   'greater',
#   'good',
#   'plymouth',
#   'team',
#   'cycl',
#   'year'],
#  ['consign', 'coal', 'histori', 'unfccc', 'cop'],
#  ['yellowcak', 'geigercount', 'mention', 'benefiz', 'mass', 'awar'],
#  ['aye', 'cos', 'pledg', 'pari', 'agreement', 'pure', 'theatr'],
#  ['action',
#   'philanthropi',
#   'fund',
#   'indigen',
#   'lead',
#   'effort',
#   'priorit',
#   'indigen',
#   'right',
#   'fundament',
#   'avert',
#   'global',
#   'climat',
#   'crisi',
#   'genfund'],
#  ['ask',
#   'weapon',
#   'manufactur',
#   'deploy',
#   'contribut',
#   'global',
#   'warm',
#   'let',
#   'join',
#   'think'],
#  ['new', 'film', 'order'],
#  ['unlimit',
#   'sand',
#   'money',
#   'win',
#   'save',
#   'sand',
#   'half',
#   'billion',
#   'dollar',
#   'dredg',
#   'certain'],
#  ['caus', 'abus', 'despit', 'member', 'chanc'],
#  ['saw',
#   'chart',
#   'economist',
#   'wonder',
#   'leap',
#   'renew',
#   'actual',
#   'beat',
#   'close'],
#  ['energi',
#   'come',
#   'fossil',
#   'fuel',
#   'fact',
#   'use',
#   'million',
#   'barrel',
#   'crude',
#   'oil',
#   'year',
#   'litr',
#   'crude',
#   'oil',
#   'person',
#   'year'],
#  ['multilevel',
#   'action',
#   'pavilion',
#   'onlin',
#   'person',
#   'pavilion',
#   'blue',
#   'zone',
#   'nation',
#   'discuss',
#   'decis',
#   'local',
#   'relev',
#   'thank',
#   'constitu',
#   'home',
#   'citi',
#   'region',
#   'join'],
#  ['miss',
#   'permafrost',
#   'day',
#   'cop',
#   'worri',
#   'video',
#   'avail',
#   'watch',
#   'cryospher',
#   'pavilion',
#   'facebook',
#   'page'],
#  ['failur',
#   'provid',
#   'critic',
#   'financ',
#   'loss',
#   'damag',
#   'measur',
#   'friend',
#   'live',
#   'livelihood',
#   'communiti',
#   'immor',
#   'code',
#   'red',
#   'code',
#   'red',
#   'tri',
#   'harder',
#   'pls',
#   'hear',
#   'speech',
#   'barbado',
#   'mia',
#   'mottley'],
#  ['effort',
#   'develop',
#   'new',
#   'fund',
#   'mechan',
#   'establish',
#   'partnership',
#   'support',
#   'expand',
#   'access',
#   'transit',
#   'green',
#   'energi',
#   'job',
#   'creation'],
#  ['wait', 'killer', 'punch', 'end', 'final', 'unlimit', 'invest'],
#  ['lullabi'],
#  ['nan'],
#  ['chanc', 'get'],
#  ['busi',
#   'today',
#   'plan',
#   'multi',
#   'megawatt',
#   'plant',
#   'produc',
#   'healthi',
#   'heat',
#   'citi',
#   'industri',
#   'miss',
#   'burn',
#   'fossil',
#   'fuel',
#   'illeg'],
#  ['sure',
#   'month',
#   'look',
#   'think',
#   'absolut',
#   'insan',
#   'hold',
#   'person',
#   'pandem',
#   'rag'],
#  ['close',
#   'perfect',
#   'right',
#   'expect',
#   'better',
#   'head',
#   'govern',
#   'hoard',
#   'peopl',
#   'take',
#   'glasgow',
#   'lot',
#   'miss',
#   'opportun'],
#  ['countri',
#   'need',
#   'leader',
#   'lead',
#   'corrupt',
#   'liar',
#   'intent',
#   'good',
#   'sever',
#   'time',
#   'constraint',
#   'pretti',
#   'use',
#   'technolog',
#   'allow',
#   'instant',
#   'meet',
#   'distanc'],
#  ['hope',
#   'ambiti',
#   'commit',
#   'countri',
#   'especi',
#   'lead',
#   'emitt',
#   'like',
#   'china',
#   'faculti',
#   'director',
#   'alex',
#   'wang',
#   'comment',
#   'countri',
#   'climat',
#   'commit',
#   'potenti',
#   'shake',
#   'world'],
#  ['look',
#   'forward',
#   'day',
#   'activ',
#   'friday',
#   'team',
#   'start',
#   'earli',
#   'panel'],
#  ['listen',
#   'press',
#   'confer',
#   'agre',
#   'thing',
#   'happen',
#   'young',
#   'peopl',
#   'push',
#   'urgenc',
#   'climat',
#   'action',
#   'agenda',
#   'methan',
#   'rule',
#   'vital'],
#  ['greta', 'thunberg', 'offici', 'speaker', 'go', 'say', 'wrong'],
#  ['need',
#   'climat',
#   'data',
#   'need',
#   'better',
#   'climat',
#   'risk',
#   'govern',
#   'precautionari',
#   'invest',
#   'principl'],
#  ['talk',
#   'promis',
#   'see',
#   'new',
#   'attitud',
#   'promot',
#   'buy',
#   'lot',
#   'pointless',
#   'shite',
#   'midwint',
#   'need',
#   'chang'],
#  ['let',
#   'pressur',
#   'let',
#   'politician',
#   'away',
#   'fals',
#   'promis',
#   'kick',
#   'road',
#   'say',
#   'day',
#   'let',
#   'support',
#   'essenti',
#   'process',
#   'framework',
#   'engag',
#   'construct'],
#  ['year', 'later', 'noth', 'chang'],
#  ['data',
#   'alert',
#   'wide',
#   'daili',
#   'volumetr',
#   'soil',
#   'moistur',
#   'data',
#   'resolut',
#   'index',
#   'wet',
#   'particular',
#   'locat',
#   'time',
#   'access',
#   'data',
#   'tool'],
#  ['see',
#   'north',
#   'american',
#   'conserv',
#   'tweet',
#   'call',
#   'bank',
#   'presid',
#   'billionair',
#   'authoritarian',
#   'head',
#   'state',
#   'like',
#   'orban',
#   'tori',
#   'leader',
#   'like',
#   'johnson',
#   'british',
#   'royal',
#   'danger',
#   'leav',
#   'wing',
#   'radic',
#   'environment',
#   'extremist',
#   'banana'],
#  ['yesterday',
#   'start',
#   'artwork',
#   'white',
#   'oil',
#   'pastel',
#   'creat',
#   'wave',
#   'blue',
#   'watercolour',
#   'sprinkl',
#   'salt',
#   'watercolour',
#   'ocean',
#   'bubbl',
#   'week',
#   'add',
#   'ocean',
#   'sea',
#   'creatur',
#   'coral',
#   'reef'],
#  ['glaswegian', 'humour'],
#  ['nan'],
#  ['day',
#   'launch',
#   'award',
#   'student',
#   'round',
#   'year',
#   'week',
#   'begin',
#   'challeng'],
#  ['look',
#   'sky',
#   'think',
#   'marvel',
#   'phenomenon',
#   'let',
#   'protect',
#   'creation',
#   'friend'],
#  ['import',
#   'statement',
#   'coalit',
#   'financ',
#   'minist',
#   'today',
#   'basic',
#   'agre',
#   'protect',
#   'mission',
#   'critic',
#   'mitig',
#   'adapt',
#   'question',
#   'work',
#   'financ',
#   'mechan'],
#  ['actual',
#   'cheer',
#   'global',
#   'warm',
#   'activist',
#   'compar',
#   'suffragett',
#   'best',
#   'danger',
#   'delusion',
#   'sooner',
#   'global',
#   'warm',
#   'end',
#   'better'],
#  ['ahem'],
#  ['nan'],
#  ['bite',
#   'work',
#   'servic',
#   'proper',
#   'servic',
#   'amsterdam',
#   'glasgow',
#   'chang',
#   'train'],
#  ['busi',
#   'day',
#   'tomorrow',
#   'young',
#   'peopl',
#   'head',
#   'push',
#   'world',
#   'leader',
#   'action',
#   'action',
#   'link'],
#  ['think', 'shitti', 'govern', 'shut', 'car', 'industri'],
#  ['shock', 'learn', 'audienc', 'ignor'],
#  ['floor', 'insid', 'green', 'zone', 'today'],
#  ['grow', 'problem', 'anim', 'go', 'wallet'],
#  ['usa', 'china', 'india', 'australia'],
#  ['key',
#   'role',
#   'help',
#   'secur',
#   'climat',
#   'safe',
#   'futur',
#   'call',
#   'stay',
#   'true',
#   'activist',
#   'root',
#   'canada',
#   'climat',
#   'action',
#   'new',
#   'height',
#   'offset',
#   'yes',
#   'end',
#   'fossil',
#   'fuel'],
#  ['interest',
#   'report',
#   'hope',
#   'enjoy',
#   'oil',
#   'gas',
#   'industri',
#   'alloc',
#   'resourc',
#   'offshor',
#   'wind',
#   'geotherm',
#   'water',
#   'system',
#   'capit',
#   'equip',
#   'workforc',
#   'look',
#   'fair',
#   'compat'],
#  ['way',
#   'govern',
#   'world',
#   'listen',
#   'direct',
#   'action',
#   'adult',
#   'trust',
#   'right',
#   'right',
#   'life',
#   'planet',
#   'fit',
#   'life',
#   'need',
#   'futur'],
#  ['real',
#   'climat',
#   'action',
#   'urgent',
#   'emiss',
#   'cut',
#   'need',
#   'stop',
#   'climat',
#   'pollut',
#   'happen',
#   'sourc',
#   'delay',
#   'greenwash',
#   'need',
#   'net',
#   'zero',
#   'offset',
#   'deliv',
#   'urgent',
#   'action',
#   'phase',
#   'fossil',
#   'fuel',
#   'cut',
#   'emiss'],
#  ['super', 'spreader', 'event'],
#  ['vote',
#   'far',
#   'right',
#   'extremist',
#   'prove',
#   'vote',
#   'sewag',
#   'mouth',
#   'covid',
#   'death',
#   'level',
#   'atroc',
#   'corrupt',
#   'new',
#   'fossil',
#   'fuel',
#   'develop',
#   'green',
#   'vote',
#   'rocket',
#   'recent',
#   'elect'],
#  ['follow',
#   'follow',
#   'care',
#   'planet',
#   'watch',
#   'rnl',
#   'today',
#   'watch',
#   'share',
#   'tag'],
#  ['rare',
#   'watch',
#   'rarer',
#   'green',
#   'panel',
#   'take',
#   'global',
#   'intern',
#   'confer'],
#  ['love', 'meet', 'today', 'talk', 'spot', 'mask'],
#  ['intern', 'clean', 'technolog', 'plan', 'announc'],
#  ['gist'],
#  ['good',
#   'news',
#   'industri',
#   'compani',
#   'boost',
#   'target',
#   'green',
#   'climat',
#   'fight'],
#  ['global', 'pledg', 'save', 'skeptic', 'warrant'],
#  ['eat',
#   'meat',
#   'agricultur',
#   'livestock',
#   'produc',
#   'methan',
#   'respons',
#   'global',
#   'warm',
#   'cleaner',
#   'spray',
#   'switch',
#   'soap',
#   'shower',
#   'gel',
#   'plastic',
#   'wast',
#   'compost',
#   'food',
#   'wast',
#   'reduc',
#   'gas',
#   'landfil',
#   'sit'],
#  ...]

# %%
en_df['root'] = stop_w_all

# %%
en_df
# Out:
#            twitter_id                                            content  \
# 0        aquitainexox  @Banterm42404691 @MrHarryCole Absolutely one s...
# 1        GEC_JCM_Info  Please join us at a #COP26 side event "Impleme...
# 2              zpnine  #India’s huge solar uptake has boosted #climat...
# 3             PGDynes  The concrete needed to accommodate 2 billion m...
# 4             Xplorit  #WestVirginia Senator &amp; Ennersystams fraud...
# ...               ...                                                ...
# 5949   AqsaYounasRana  ClimateChange is no more only a challenge, it’...
# 5950       pete4peace  We confronted the coal baron this morning! Fuc...
# 5951  mmill_landscape  Feeling simply disgusted by countries such as ...
# 5952      KarynCaplan  🚨 Join us in calling for @Google and #Facebook...
# 5953           DrDuly  There is no doubt! "The science is clear: to k...
#
#                                           removed_links  \
# 0     @Banterm42404691 @MrHarryCole Absolutely one s...
# 1     Please join us at a #COP26 side event "Impleme...
# 2     #India’s huge solar uptake has boosted #climat...
# 3     The concrete needed to accommodate 2 billion m...
# 4     #WestVirginia Senator &amp; Ennersystams fraud...
# ...                                                 ...
# 5949  ClimateChange is no more only a challenge, it’...
# 5950  We confronted the coal baron this morning! Fuc...
# 5951  Feeling simply disgusted by countries such as ...
# 5952  🚨 Join us in calling for @Google and #Facebook...
# 5953  There is no doubt! "The science is clear: to k...
#
#                                           removed_users  \
# 0       Absolutely one self indulgent ego trip!! #COP26
# 1     Please join us at a #COP26 side event "Impleme...
# 2     #India’s huge solar uptake has boosted #climat...
# 3     The concrete needed to accommodate 2 billion m...
# 4     #WestVirginia Senator &amp; Ennersystams fraud...
# ...                                                 ...
# 5949  ClimateChange is no more only a challenge, it’...
# 5950  We confronted the coal baron this morning! Fuc...
# 5951  Feeling simply disgusted by countries such as ...
# 5952  🚨 Join us in calling for  and #Facebook () to ...
# 5953  There is no doubt! "The science is clear: to k...
#
#                                        removed_hashtags  \
# 0             Absolutely one self indulgent ego trip!!
# 1     Please join us at a  side event "Implementing ...
# 2     ’s huge solar uptake has boosted  goals, says ...
# 3     The concrete needed to accommodate 2 billion m...
# 4      Senator &amp; Ennersystams fraud . gets a pro...
# ...                                                 ...
# 5949  ClimateChange is no more only a challenge, it’...
# 5950  We confronted the coal baron this morning! Fuc...
# 5951  Feeling simply disgusted by countries such as ...
# 5952  🚨 Join us in calling for  and  () to stop prom...
# 5953  There is no doubt! "The science is clear: to k...
#
#                                              removed_av  \
# 0             Absolutely one self indulgent ego trip!!
# 1     Please join us at a  side event "Implementing ...
# 2     ’s huge solar uptake has boosted  goals, says ...
# 3     The concrete needed to accommodate 2 billion m...
# 4      Senator &amp; Ennersystams fraud . gets a pro...
# ...                                                 ...
# 5949  ClimateChange is no more only a challenge, it’...
# 5950  We confronted the coal baron this morning! Fuc...
# 5951  Feeling simply disgusted by countries such as ...
# 5952  🚨 Join us in calling for  and  () to stop prom...
# 5953  There is no doubt! "The science is clear: to k...
#
#                                                  tokens  \
# 0                    absolutely self indulgent ego trip
# 1     join event implement joint credit mechanism jc...
# 2            huge solar uptake boost goals say minister
# 3     concrete need accommodate billion people citie...
# 4     senator amp ennersystams fraud get proper welc...
# ...                                                 ...
# 5949  climatechange challenge crisis soon catastroph...
# 5950                   confront coal baron morning fuck
# 5951  feel simply disgust countries sign decrease st...
# 5952  join call stop promote fund climate denial pub...
# 5953  doubt science clear warm degrees cut global em...
#
#                                              lemmatized lang  \
# 0                    absolutely self indulgent ego trip   en
# 1     join event implement joint credit mechanism jc...   en
# 2            huge solar uptake boost goals say minister   en
# 3     concrete need accommodate billion people citie...   en
# 4     senator amp ennersystams fraud get proper welc...   en
# ...                                                 ...  ...
# 5949  climatechange challenge crisis soon catastroph...   en
# 5950                   confront coal baron morning fuck   en
# 5951  feel simply disgust countries sign decrease st...   en
# 5952  join call stop promote fund climate denial pub...   en
# 5953  doubt science clear warm degrees cut global em...   en
#
#                                               stop_word  \
# 0              [absolutely, self, indulgent, ego, trip]
# 1     [join, event, implement, joint, credit, mechan...
# 2     [huge, solar, uptake, boost, goals, say, minis...
# 3     [concrete, need, accommodate, billion, people,...
# 4     [senator, ennersystams, fraud, get, proper, we...
# ...                                                 ...
# 5949  [climatechange, challenge, crisis, soon, catas...
# 5950             [confront, coal, baron, morning, fuck]
# 5951  [feel, simply, disgust, countries, sign, decre...
# 5952  [join, call, stop, promote, fund, climate, den...
# 5953  [doubt, science, clear, warm, degrees, cut, gl...
#
#                                                    root
# 0                    [absolut, self, indulg, ego, trip]
# 1     [join, event, implement, joint, credit, mechan...
# 2        [huge, solar, uptak, boost, goal, say, minist]
# 3     [concret, need, accommod, billion, peopl, citi...
# 4     [senat, ennersystam, fraud, get, proper, welco...
# ...                                                 ...
# 5949  [climatechang, challeng, crisi, soon, catastro...
# 5950                [confront, coal, baron, morn, fuck]
# 5951  [feel, simpli, disgust, countri, sign, decreas...
# 5952  [join, call, stop, promot, fund, climat, denia...
# 5953  [doubt, scienc, clear, warm, degre, cut, globa...
#
# [5954 rows x 11 columns]

# %% [markdown]
# ### stem/root in string form for each tweet

# %%
root_join_all = []
for i in range(len(en_df['root'])):
    root_join = " ".join(en_df['root'][i])
    root_join_all.append(root_join)

# %%
en_df['root_string'] = root_join_all

# %%
en_df.to_csv("root_string_df.csv", index=False)
